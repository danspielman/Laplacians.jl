# %%
using Revise
using Laplacians
using Pkg
@show Pkg.pathof(Laplacians)
using SparseArrays
using LinearAlgebra
# Out:
# Pkg.pathof(Laplacians) = "/Users/rjkyng/Dropbox/Repos/Laplacians.jl/src/Laplacians.jl"

# %%
using Plots

# %%
s1 = 4
s2 = 9
s3 = 6
@time A = ggrid3(s1,s2,s3);
# Out:
#   0.000044 seconds (30 allocations: 65.984 KiB)

# %%
x,y,z = ggrid3coords(s1,s2,s3);

# %%
p = plot_graph_weighted(A,x,y,z;dots=false);

# %%
s1 = 12
s2 = 12
s3 = 12
b1,b2,b3 = 2,2,2
@time A = ggrid3_checkered(s1,s2,s3,b1,b2,b3,10);
x,y,z = ggrid3coords(s1,s2,s3);
# Out:
#   0.000247 seconds (41 allocations: 552.453 KiB)

# %%
p = plot_graph_weighted(A,x,y,z;dots=false);

# %%
s1 = 12
s2 = 12
s3 = 12
b1,b2,b3 = 2,2,3
@time A = ggrid3_checkered(s1,s2,s3,b1,b2,b3,10);
x,y,z = ggrid3coords(s1,s2,s3);
# Out:
#   0.000353 seconds (41 allocations: 552.453 KiB)

# %%
p = plot_graph_weighted(A,x,y,z;dots=false);

# %%
s1 = 12
s2 = 12
s3 = 20
b1,b2,b3 = 2,2,3
@time A = ggrid3_checkered(s1,s2,s3,b1,b2,b3,10);
x,y,z = ggrid3coords(s1,s2,s3);
# Out:
#   0.000898 seconds (46 allocations: 928.719 KiB)

# %%
p = plot_graph_weighted(A,x,y,z;dots=false);
