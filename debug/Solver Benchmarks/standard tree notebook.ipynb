# %%
using Laplacians
using ProfileView

# %%
include("../../src/linkedListSamplingTreeSolver.jl")
# Out:
# constructLowerTriangularMat (generic function with 1 method)

# %%
n = 100000;
a = chimera(n, 1);
b = rand(n); b = b - mean(b);

# %%
@time f = samplingSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# Time to build the tree and compute the stretch: elapsed time: 1.048053007 seconds
#  78.558426 seconds (165.20 M allocations: 9.536 GB, 57.90% gc time)

# %%
@profile _,gOp,_,_,_ = buildSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# Time to build the tree and compute the stretch: elapsed time: 1.378972087 seconds

# %%
ProfileView.view()
# Out:
# WARNING: The profile data buffer is full; profiling probably terminated
# before your program finished. To profile for longer runs, call Profile.init
# with a larger buffer and/or larger delay.
# ProfileView.ProfileData(8048x13 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}:
#  RGB{U8}(1.0,1.0,1.0)        …  RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)   …  RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)   …  RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  ⋮                           ⋱
#  RGB{U8}(0.196,0.706,0.306)     RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.196,0.706,0.306)     RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.196,0.706,0.306)     RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.196,0.706,0.306)     RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.196,0.706,0.306)  …  RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.196,0.706,0.306)     RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.102,0.635,1.0)       RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.102,0.635,1.0)       RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.824,0.647,0.09)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.0,0.871,0.902)    …  RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0)
#  RGB{U8}(0.91,0.439,0.867)      RGB{U8}(1.0,1.0,1.0),Dict(0x000000031da0f7d6=>Base.Profile.LineInfo("samplingLDL","/Users/serbanstan/git/Laplacians.jl/src/samplingTreeSolver.jl",182,"",-1,false,13381990358),0x000000031d9e012d=>Base.Profile.LineInfo("+","sparse/sparsematrix.jl",783,"sparse/sparsematrix.jl",1010,false,13381796141),0x000000031da1a71f=>Base.Profile.LineInfo("jlcall_llsAdd_22172","",-1,"",-1,true,13382035231),0x0000000107d32043=>Base.Profile.LineInfo("push_root","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1723,"",-1,true,4426244163),0x0000000107cb2139=>Base.Profile.LineInfo("mtcache_hash_lookup","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gf.c",158,"/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gf.c",259,true,4425720121),0x0000000107cb2078=>Base.Profile.LineInfo("jl_method_table_assoc_exact","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gf.c",246,"",-1,true,4425719928),0x000000031da1af0e=>Base.Profile.LineInfo("llsPurge","/Users/serbanstan/git/Laplacians.jl/src/linkedListStorage.jl",101,"",-1,false,13382037262),0x000000031da1af29=>Base.Profile.LineInfo("llsPurge","/Users/serbanstan/git/Laplacians.jl/src/linkedListStorage.jl",101,"",-1,false,13382037289),0x000000031da13aa8=>Base.Profile.LineInfo("find_root_impl!","/Users/serbanstan/.julia/v0.4/DataStructures/src/disjoint_set.jl",36,"",-1,false,13382007464),0x0000000107d33068=>Base.Profile.LineInfo("jl_gc_allocobj","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",2297,"",-1,true,4426248296),0x0000000107d1f854=>Base.Profile.LineInfo("jl_array_grow_end","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/array.c",640,"",-1,true,4426168404),0x0000000107d344a3=>Base.Profile.LineInfo("gc_push_root","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1596,"/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1595,true,4426253475),0x00007fff97e3d04c=>Base.Profile.LineInfo("_platform_memmove\$VARIANT\$Haswell","/usr/lib/system/libsystem_platform.dylib",-1,"",-1,true,140735741677644),0x000000031da1a701=>Base.Profile.LineInfo("jlcall_llsAdd_22172","",-1,"",-1,true,13382035201),0x0000000107d32e4d=>Base.Profile.LineInfo("jl_gc_allocobj","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",2291,"",-1,true,4426247757),0x0000000107d3173f=>Base.Profile.LineInfo("push_root","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1621,"",-1,true,4426241855),0x000000031da1af51=>Base.Profile.LineInfo("llsPurge","/Users/serbanstan/git/Laplacians.jl/src/linkedListStorage.jl",103,"",-1,false,13382037329),0x000000031da16689=>Base.Profile.LineInfo("randishKruskal","/Users/serbanstan/git/Laplacians.jl/src/randTrees.jl",22,"",-1,false,13382018697),0x000000031da1adac=>Base.Profile.LineInfo("llsPurge","/Users/serbanstan/git/Laplacians.jl/src/linkedListStorage.jl",88,"",-1,false,13382036908),0x000000031da170fe=>Base.Profile.LineInfo("sample","/Users/serbanstan/git/Laplacians.jl/src/sampler.jl",65,"",-1,false,13382021374),0x000000031da1b007=>Base.Profile.LineInfo("llsPurge","/Users/serbanstan/git/Laplacians.jl/src/linkedListStorage.jl",112,"",-1,false,13382037511),0x0000000107d2fd73=>Base.Profile.LineInfo("__pool_alloc","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1080,"/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",2317,true,4426235251),0x000000031da0f9f2=>Base.Profile.LineInfo("samplingLDL","/Users/serbanstan/git/Laplacians.jl/src/samplingTreeSolver.jl",205,"",-1,false,13381990898),0x0000000107d317bc=>Base.Profile.LineInfo("find_region","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",419,"/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1630,true,4426241980),0x000000031da0e143=>Base.Profile.LineInfo("buildSolver","/Users/serbanstan/git/Laplacians.jl/src/samplingTreeSolver.jl",46,"",-1,false,13381984579),0x0000000107d31720=>Base.Profile.LineInfo("push_root","/Users/osx/buildbot/slave/package_osx10_9-x64/build/src/gc.c",1619,"",-1 ...
#  ProfileView.TagData(0x0000000000000000,-1)  …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000030c46c549,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ⋮                                           ⋱
#  ProfileView.TagData(0x00007fff97e3d03b,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e3d000,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e3d000,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e3d03f,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e3d03f,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e3cf24,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e397c4,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fff97e397c4,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000031da1a701,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x000000031558e8c0,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000315591a50,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000315591a50,0)      ProfileView.TagData(0x0000000000000000,-1),12)

# %%
@time checkError(gOp)
# Out:
# LoadError: UndefVarError: gOp not defined
# while loading In[7], in expression starting on line 155

# %%
@time norm(lap(a) * f(b) - b)
# Out:
# LoadError: UndefVarError: f not defined
# while loading In[7], in expression starting on line 155

# %%
@time f = samplingSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# LoadError: InterruptException:
# while loading In[8], in expression starting on line 155
#
#  in sample at /Users/serbanstan/git/Laplacians.jl/src/sampler.jl:61
#  in pop! at /Users/serbanstan/git/Laplacians.jl/src/sampler.jl:91
#  in randishKruskal at /Users/serbanstan/git/Laplacians.jl/src/randTrees.jl:21
#  in buildSolver at /Users/serbanstan/git/Laplacians.jl/src/samplingTreeSolver.jl:41
#  in samplingSolver at /Users/serbanstan/git/Laplacians.jl/src/samplingTreeSolver.jl:14

# %%
@time norm(lap(a) * f(b) - b)
# Out:
# LoadError: UndefVarError: f not defined
# while loading In[9], in expression starting on line 155

# %%
@time _,gOp,_,_,_ = buildSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# LoadError: InterruptException:
# while loading In[10], in expression starting on line 155
#
#  in sparse at sparse/csparse.jl:52
#  in randishKruskal at /Users/serbanstan/git/Laplacians.jl/src/randTrees.jl:29
#  in buildSolver at /Users/serbanstan/git/Laplacians.jl/src/samplingTreeSolver.jl:41

# %%
@time checkError(gOp)
# Out:
# LoadError: UndefVarError: gOp not defined
# while loading In[11], in expression starting on line 155
