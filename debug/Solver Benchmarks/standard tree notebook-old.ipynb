# %%
using Laplacians
using ProfileView

# %%
include("../../src/oldSamplingTreeSolver.jl")
# Out:
# constructLowerTriangularMat (generic function with 1 method)

# %%
n = 100000;
a = chimera(n, 1);
b = rand(n); b = b - mean(b);

# %%
samplingSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# Time to build the tree and compute the stretch: elapsed time: 1.012987719 seconds

# %%
@time f = samplingSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# Time to build the tree and compute the stretch: elapsed time: 0.999014608 seconds
#   8.625450 seconds (15.57 M allocations: 3.522 GB, 30.74% gc time)

# %%
@time norm(lap(a) * f(b) - b)
# Out:
# PCG stopped after: 21 iterations with relative error 8.906741431783024e-7.
#   2.348897 seconds (5.18 M allocations: 234.225 MB, 1.82% gc time)
# 8.13110723520304e-5

# %%
@time _,gOp,_,_,_ = buildSolver(a, eps = 0.5, sampConst = 0.005, k = 5.0, beta = 5.0);
# Out:
# Time to build the tree and compute the stretch: elapsed time: 1.116234484 seconds
#   7.029898 seconds (7.14 M allocations: 3.331 GB, 24.75% gc time)

# %%
@time checkError(gOp)
# Out:
#  11.025104 seconds (51.36 M allocations: 1.172 GB, 8.09% gc time)
# 0.7868498433011445
