# %%
using Laplacians

# %%
include("../../../src/isotonicIPM.jl")
include("../../../src/samplingSolver.jl")
# Out:
# computeCN (generic function with 1 method)

# %%
function generateInput(n,i)
    a = wtedChimera(n,i);
    b = zeros(Float64,n);
    b[1] = 1;
    b[n] = -1;
    v = cg(lap(a),b,verbose=true); # use any other solver
    v = v / (v[1] - v[n])

    p = sortperm(v);
    ap = a[p,p];
    # vp = v[p]
    vp = v[p] + rand(n) / sqrt(n);
    at = triu(ap);
    
    return at,vp
end
# Out:
# generateInput (generic function with 1 method)

# %% [markdown]
# ### First, testing the isotonic regression with augTree solver

# %%
ts_aug = []
accs_aug = []
itercounts_aug = []
epss_aug = []

for i in 1:200
    for eps in [0.01, 0.001, 0.0001]
        a,v = generateInput(10000,i)
        tic()
        (x,acc,itercount) = isotonicIPMrelEps(a,v,eps);
        push!(ts_aug, toc());
        push!(accs_aug, acc)
        push!(itercounts_aug, itercount)
        push!(epss_aug, eps)
    end
    
    println()
    println("Done for ", i)
    println()
end
# Out:
# CG stopped after: 56338 iterations with relative error 9.85099007223889e-7.
# elapsed time: 19.47963739 seconds
# CG stopped after: 56338 iterations with relative error 9.85099007223889e-7.
# elapsed time: 17.566273958 seconds
# CG stopped after: 56338 iterations with relative error 9.85099007223889e-7.
# elapsed time: 18.563989351 seconds
#
# Done for 1

# %% [markdown]
# ### Now, isotonic regression with samplingSolver

# %%
ts_samp = []
accs_samp = []
itercounts_samp = []
epss_samp = []

for i in 1:200
    for eps in [0.01, 0.001, 0.0001]
        a,v = generateInput(10000,i)
        tic()
        (x,acc,itercount) = isotonicIPMrelEps(a,v,eps,
            (H -> samplingSolver(adj(H)[1], adj(H)[2], eps=0.5, sampConst=0.3, beta=1e5, tol=1e-1,maxits=1000)));
        push!(ts_samp, toc());
        push!(accs_samp, acc)
        push!(itercounts_samp, itercount)
        push!(epss_samp, eps)
    end
    
    println()
    println("Done for ", i)
    println()
end
# Out:
# CG stopped after: 56338 iterations with relative error 9.85099007223889e-7.
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048269655079515
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.113842164 seconds
#
# The total size of the linked list data structure should be at most 3254004
# The actual size is 12100
#
# nnz in U matrix: 31199
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04827529627908
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.080527443 seconds
#
# The total size of the linked list data structure should be at most 3254005
# The actual size is 12100
#
# nnz in U matrix: 31198
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048267984124664
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.080948181 seconds
#
# The total size of the linked list data structure should be at most 3254004
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04827495306291
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.133010943 seconds
#
# The total size of the linked list data structure should be at most 3254005
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0482802787636
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.078667301 seconds
#
# The total size of the linked list data structure should be at most 3254005
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04829020458787
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083051439 seconds
#
# The total size of the linked list data structure should be at most 3254005
# The actual size is 12100
#
# nnz in U matrix: 31224
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048307155421305
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084368872 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31290
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04830539976856
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088635094 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31199
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048307565938174
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083411125 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04830970229528
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.091998919 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31197
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048324990070874
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.095614863 seconds
#
# The total size of the linked list data structure should be at most 3254007
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04833818279369
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085181369 seconds
#
# The total size of the linked list data structure should be at most 3254007
# The actual size is 12100
#
# nnz in U matrix: 31201
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04834049998836
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088909728 seconds
#
# The total size of the linked list data structure should be at most 3254007
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048336714634075
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.076523865 seconds
#
# The total size of the linked list data structure should be at most 3254007
# The actual size is 12100
#
# nnz in U matrix: 31277
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04833211604951
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.073165059 seconds
#
# The total size of the linked list data structure should be at most 3254007
# The actual size is 12100
#
# nnz in U matrix: 31227
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048305066683646
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079473995 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31195
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04861752840391
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.098846381 seconds
#
# The total size of the linked list data structure should be at most 3254019
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04845883534371
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079611712 seconds
#
# The total size of the linked list data structure should be at most 3254012
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048654698811724
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.078748949 seconds
#
# The total size of the linked list data structure should be at most 3254021
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048501957260065
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081553167 seconds
#
# The total size of the linked list data structure should be at most 3254014
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04848538639021
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.072589701 seconds
#
# The total size of the linked list data structure should be at most 3254014
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04856998334637
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081738 seconds
#
# The total size of the linked list data structure should be at most 3254017
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04855033169941
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.07997997 seconds
#
# The total size of the linked list data structure should be at most 3254016
# The actual size is 12100
#
# nnz in U matrix: 31197
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04855815715556
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.075198525 seconds
#
# The total size of the linked list data structure should be at most 3254017
# The actual size is 12100
#
# nnz in U matrix: 31203
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048785724230115
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.078033292 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31208
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0487826098737
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081626977 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04878100577629
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.078761661 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877641482488
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084131616 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877701122623
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.077464133 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31197
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877720259774
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082258888 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.049175876687144
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081355373 seconds
#
# The total size of the linked list data structure should be at most 3254043
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0483113119976
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082905394 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31212
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04865403446324
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.07841027 seconds
#
# The total size of the linked list data structure should be at most 3254021
# The actual size is 12100
#
# nnz in U matrix: 31225
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04871872345925
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.077751433 seconds
#
# The total size of the linked list data structure should be at most 3254023
# The actual size is 12100
#
# nnz in U matrix: 31218
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877432783562
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.076493938 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31205
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877721319755
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.077468638 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04910888896265
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079253348 seconds
#
# The total size of the linked list data structure should be at most 3254040
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04832140243635
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.095751582 seconds
#
# The total size of the linked list data structure should be at most 3254007
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04861024102088
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079143439 seconds
#
# The total size of the linked list data structure should be at most 3254019
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04872915480808
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083020229 seconds
#
# The total size of the linked list data structure should be at most 3254024
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877523886525
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079815738 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048777267980505
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.077035044 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31922
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.049243412939155
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.0796167 seconds
#
# The total size of the linked list data structure should be at most 3254046
# The actual size is 12100
#
# nnz in U matrix: 31308
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04830986633234
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.076043608 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31201
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048814911982966
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.076058023 seconds
#
# The total size of the linked list data structure should be at most 3254028
# The actual size is 12100
#
# nnz in U matrix: 31212
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04871799279768
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.134048265 seconds
#
# The total size of the linked list data structure should be at most 3254023
# The actual size is 12100
#
# nnz in U matrix: 31199
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877419094773
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079820565 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877746506396
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084093036 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.049145006660936
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082785579 seconds
#
# The total size of the linked list data structure should be at most 3254042
# The actual size is 12100
#
# nnz in U matrix: 31218
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04892249963018
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.099689878 seconds
#
# The total size of the linked list data structure should be at most 3254032
# The actual size is 12100
#
# nnz in U matrix: 31236
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048976129381714
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.077529396 seconds
#
# The total size of the linked list data structure should be at most 3254034
# The actual size is 12100
#
# nnz in U matrix: 31201
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048717851648114
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084129571 seconds
#
# The total size of the linked list data structure should be at most 3254023
# The actual size is 12100
#
# nnz in U matrix: 31207
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877579376572
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08361987 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04877959553723
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081710586 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04837784284024
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079227714 seconds
#
# The total size of the linked list data structure should be at most 3254009
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048930573147686
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08018835 seconds
#
# The total size of the linked list data structure should be at most 3254032
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04865950553539
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.080368369 seconds
#
# The total size of the linked list data structure should be at most 3254021
# The actual size is 12100
#
# nnz in U matrix: 31210
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04871430754469
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.128478878 seconds
#
# The total size of the linked list data structure should be at most 3254023
# The actual size is 12100
#
# nnz in U matrix: 31212
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048776294526874
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08562656 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31213
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048778258330195
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085235089 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31199
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0483701260748
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085185861 seconds
#
# The total size of the linked list data structure should be at most 3254009
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04831293339297
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.097890348 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31223
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048688522486295
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08223267 seconds
#
# The total size of the linked list data structure should be at most 3254022
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04878971828148
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079715998 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31210
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04878746429186
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08081886 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31243
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04879263106252
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081870522 seconds
#
# The total size of the linked list data structure should be at most 3254027
# The actual size is 12100
#
# nnz in U matrix: 31226
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04878648451299
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.078817411 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31225
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04878633276739
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.07886417 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04837955032243
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.156548999 seconds
#
# The total size of the linked list data structure should be at most 3254009
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04900159375714
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083000739 seconds
#
# The total size of the linked list data structure should be at most 3254035
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04871431724311
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083489433 seconds
#
# The total size of the linked list data structure should be at most 3254023
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04874192710268
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083704293 seconds
#
# The total size of the linked list data structure should be at most 3254024
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048805873376224
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084848981 seconds
#
# The total size of the linked list data structure should be at most 3254027
# The actual size is 12100
#
# nnz in U matrix: 31235
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048809162129956
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084832762 seconds
#
# The total size of the linked list data structure should be at most 3254027
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048349109756494
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.156455324 seconds
#
# The total size of the linked list data structure should be at most 3254008
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.049950321056265
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083192122 seconds
#
# The total size of the linked list data structure should be at most 3254076
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048762540604585
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084287853 seconds
#
# The total size of the linked list data structure should be at most 3254025
# The actual size is 12100
#
# nnz in U matrix: 31200
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048808673385594
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085153462 seconds
#
# The total size of the linked list data structure should be at most 3254027
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0488619150539
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082534856 seconds
#
# The total size of the linked list data structure should be at most 3254030
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04885879609536
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087562532 seconds
#
# The total size of the linked list data structure should be at most 3254029
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04838318658396
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083832593 seconds
#
# The total size of the linked list data structure should be at most 3254009
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04986737089929
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079949107 seconds
#
# The total size of the linked list data structure should be at most 3254072
# The actual size is 12100
#
# nnz in U matrix: 31245
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04878082972463
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085218139 seconds
#
# The total size of the linked list data structure should be at most 3254026
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0485824232626
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083956972 seconds
#
# The total size of the linked list data structure should be at most 3254018
# The actual size is 12100
#
# nnz in U matrix: 31213
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048543262861834
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083460126 seconds
#
# The total size of the linked list data structure should be at most 3254016
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04860057470539
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083573213 seconds
#
# The total size of the linked list data structure should be at most 3254018
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04881566570455
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088718703 seconds
#
# The total size of the linked list data structure should be at most 3254028
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04889829242262
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.094459359 seconds
#
# The total size of the linked list data structure should be at most 3254031
# The actual size is 12100
#
# nnz in U matrix: 31197
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.049228603476365
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083154756 seconds
#
# The total size of the linked list data structure should be at most 3254045
# The actual size is 12100
#
# nnz in U matrix: 31231
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048553774244006
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085009016 seconds
#
# The total size of the linked list data structure should be at most 3254016
# The actual size is 12100
#
# nnz in U matrix: 31268
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048572590086174
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082710979 seconds
#
# The total size of the linked list data structure should be at most 3254017
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04861277209758
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083648246 seconds
#
# The total size of the linked list data structure should be at most 3254019
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.05100202676008
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082892227 seconds
#
# The total size of the linked list data structure should be at most 3254120
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.050569961308945
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.091833329 seconds
#
# The total size of the linked list data structure should be at most 3254102
# The actual size is 12100
#
# nnz in U matrix: 31195
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04929214074996
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.086953265 seconds
#
# The total size of the linked list data structure should be at most 3254048
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04912421291886
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084791939 seconds
#
# The total size of the linked list data structure should be at most 3254041
# The actual size is 12100
#
# nnz in U matrix: 31201
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.05445404081925
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.122763027 seconds
#
# The total size of the linked list data structure should be at most 3254266
# The actual size is 12100
#
# nnz in U matrix: 31208
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.05443438595288
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088739525 seconds
#
# The total size of the linked list data structure should be at most 3254266
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.049722908694186
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087237623 seconds
#
# The total size of the linked list data structure should be at most 3254066
# The actual size is 12100
#
# nnz in U matrix: 31195
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04892190015759
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.079139055 seconds
#
# The total size of the linked list data structure should be at most 3254032
# The actual size is 12100
#
# nnz in U matrix: 31216
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04868895294988
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085320965 seconds
#
# The total size of the linked list data structure should be at most 3254022
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04910836468222
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085918876 seconds
#
# The total size of the linked list data structure should be at most 3254040
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04925471640647
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.101435089 seconds
#
# The total size of the linked list data structure should be at most 3254046
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04903320243032
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082039343 seconds
#
# The total size of the linked list data structure should be at most 3254037
# The actual size is 12100
#
# nnz in U matrix: 31199
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04917058413658
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081585241 seconds
#
# The total size of the linked list data structure should be at most 3254043
# The actual size is 12100
#
# nnz in U matrix: 31200
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04917148552054
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082710724 seconds
#
# The total size of the linked list data structure should be at most 3254043
# The actual size is 12100
#
# nnz in U matrix: 31193
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04917331747626
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087063614 seconds
#
# The total size of the linked list data structure should be at most 3254043
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048729371114554
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082426083 seconds
#
# The total size of the linked list data structure should be at most 3254024
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048609171209044
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.090908653 seconds
#
# The total size of the linked list data structure should be at most 3254019
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04922330522569
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.130658066 seconds
#
# The total size of the linked list data structure should be at most 3254045
# The actual size is 12100
#
# nnz in U matrix: 31222
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04918330404977
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.089286123 seconds
#
# The total size of the linked list data structure should be at most 3254043
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04959080384279
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.106736849 seconds
#
# The total size of the linked list data structure should be at most 3254060
# The actual size is 12100
#
# nnz in U matrix: 31205
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04898703025058
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088089494 seconds
#
# The total size of the linked list data structure should be at most 3254035
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04921254022839
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088608659 seconds
#
# The total size of the linked list data structure should be at most 3254044
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04909570937961
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.089204788 seconds
#
# The total size of the linked list data structure should be at most 3254039
# The actual size is 12100
#
# nnz in U matrix: 31194
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04876323207215
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083691423 seconds
#
# The total size of the linked list data structure should be at most 3254025
# The actual size is 12100
#
# nnz in U matrix: 31262
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0485183765895
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.086810642 seconds
#
# The total size of the linked list data structure should be at most 3254015
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04852723768169
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08714112 seconds
#
# The total size of the linked list data structure should be at most 3254015
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04893383375736
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.162868577 seconds
#
# The total size of the linked list data structure should be at most 3254033
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04865743250811
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.089453173 seconds
#
# The total size of the linked list data structure should be at most 3254021
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.05045561807373
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083009972 seconds
#
# The total size of the linked list data structure should be at most 3254097
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.05020232283165
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083637514 seconds
#
# The total size of the linked list data structure should be at most 3254086
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04889675872736
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08897014 seconds
#
# The total size of the linked list data structure should be at most 3254031
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04886418487601
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084260889 seconds
#
# The total size of the linked list data structure should be at most 3254030
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04866142085065
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081196127 seconds
#
# The total size of the linked list data structure should be at most 3254021
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048458571150405
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082650288 seconds
#
# The total size of the linked list data structure should be at most 3254012
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04842471188878
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.080176315 seconds
#
# The total size of the linked list data structure should be at most 3254011
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04830530675012
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.080956226 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04825139119418
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08484931 seconds
#
# The total size of the linked list data structure should be at most 3254004
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04823400501358
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.085376264 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04822873565466
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.086018645 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31203
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048241884241946
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088086744 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# ...
# Initial number of edges = 42374
# Average number of multiedges = 48.05020232283165
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.091517873 seconds
#
# The total size of the linked list data structure should be at most 3254086
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04889675872736
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.086300933 seconds
#
# The total size of the linked list data structure should be at most 3254031
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04886418487601
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.096858478 seconds
#
# The total size of the linked list data structure should be at most 3254030
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04866142085065
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087156859 seconds
#
# The total size of the linked list data structure should be at most 3254021
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048458571150405
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.095617915 seconds
#
# The total size of the linked list data structure should be at most 3254012
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04842471188878
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088221373 seconds
#
# The total size of the linked list data structure should be at most 3254011
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04830530675012
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081762237 seconds
#
# The total size of the linked list data structure should be at most 3254006
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04825139119418
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.081368842 seconds
#
# The total size of the linked list data structure should be at most 3254004
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04823400501358
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083772707 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04822873565466
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.08529869 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31203
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048241884241946
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.083527155 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04823098924172
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.090982547 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048213243217525
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.090709572 seconds
#
# The total size of the linked list data structure should be at most 3254002
# The actual size is 12100
#
# nnz in U matrix: 31195
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048236156886944
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.094703476 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0482360090079
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.13991787 seconds
#
# The total size of the linked list data structure should be at most 3254003
# The actual size is 12100
#
# nnz in U matrix: 31191
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04821316410676
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.091030568 seconds
#
# The total size of the linked list data structure should be at most 3254002
# The actual size is 12100
#
# nnz in U matrix: 31192
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04818026093048
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.089519255 seconds
#
# The total size of the linked list data structure should be at most 3254001
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048168135760136
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088811917 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04816368277842
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.090309041 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815545381326
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.095971569 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048156157710736
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.151017487 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0481563973804
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.089746406 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048156810903095
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.096491938 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815731459912
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.092010376 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048157416921256
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.084363042 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815646021047
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.127917279 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815853442382
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.086313054 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815698620461
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.097990947 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815695528248
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.101293999 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815860986659
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087777775 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04815689049215
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.0906952 seconds
#
# The total size of the linked list data structure should be at most 3254000
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048149444409674
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.118366706 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814869502439
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.091899999 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31196
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814724278544
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088924152 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814338229782
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.082942078 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814346915319
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087986902 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814643498168
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.087729185 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31190
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048140458700125
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.088257728 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814154507865
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.089027982 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0481415967369
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.0958543 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31189
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814151251561
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.249519359 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.0481404065651
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.162887104 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.048140401947585
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.106744863 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# rho = 101.79865410435661
# Initial number of edges = 42374
# Average number of multiedges = 48.04814086012693
# Maximum number of multiedges = 101.79865410435661
# Time to build the tree and compute the stretch: elapsed time: 0.098488765 seconds
#
# The total size of the linked list data structure should be at most 3253999
# The actual size is 12100
#
# nnz in U matrix: 31188
# elapsed time: 62.657987295 seconds
#
# Done for 1
