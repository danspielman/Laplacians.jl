# %%
using Laplacians

# %%
include("../../../src/isotonicIPM.jl")
include("../../../src/samplingSolver.jl")
# Out:
# computeCN (generic function with 1 method)

# %%
sqroot = 10
n = sqroot^2
A = grid2(sqroot,sqroot)
A = triu(A);
v = randn(n)+collect(1:n)/2;
isoTestValues = collect(1:n);
newOrder = randperm(n)
permMat = (speye(n))[1:n,newOrder];
A = permMat*A*permMat';
v = permMat*v;

# %%
@time (x,acc,itercount) = isotonicIPMrelEps(A,v,0.01);
# Out:
# So far 1 steps were made
# So far 31 steps were made
# So far 61 steps were made
#   0.080831 seconds (219.53 k allocations: 33.993 MB, 9.96% gc time)

# %%
tic()
(x,acc,itercount) = isotonicIPMrelEps(A,v,0.01,
    (H -> samplingSolver(adj(H)[1], adj(H)[2], eps=0.5, sampConst=0.3, beta=1e5, tol=1e-1,maxits=1000)));
t = toc()
# Out:
# So far 1 steps were made
# rho = 25.55920486196296
# Average number of multiedges = 9.128467716826412
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001377763 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12848729406472
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001051176 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128515817241158
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.00122057 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128690187754827
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001099854 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128838704261005
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.00192449 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12900727756887
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001643732 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.129424884124209
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000935924 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 382
# rho = 25.55920486196296
# Average number of multiedges = 9.129074459246093
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000922034 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128616116901753
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000970675 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128683594504391
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.003023513 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128755220557961
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001187762 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128966240585472
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000913059 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.129029378388847
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000956708 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128668717063308
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000857394 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128757360916262
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000886864 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128836166636317
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000911655 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12896361324105
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000920865 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128833373932395
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000903489 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12895204731135
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001485152 seconds
#
# The total size of the linked list data structure should be at most 9689
# The actual size is 1000
#
# nnz in U matrix: 383
# rho = 25.55920486196296
# Average number of multiedges = 9.128463871016532
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.00097048 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128590292112685
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000861657 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128590844980149
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000913964 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12858060255179
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001231491 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128597671529269
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001875147 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128380446911878
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001081228 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128440670924341
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001106187 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128472516016574
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000999736 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12846855412543
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000953032 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128462521652354
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.00093231 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128328343643277
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000858733 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# So far 31 steps were made
# rho = 25.55920486196296
# Average number of multiedges = 9.12834548026826
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000904014 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128352543758536
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001009899 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128361583825358
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.00097629 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128416122453206
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001015605 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128416091111914
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001005534 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128331734283421
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000896234 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128336727801525
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000883778 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.1283344215284
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001131915 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128352174811477
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001017579 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128364775347004
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.002044661 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128355820337694
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001200223 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128345436801709
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000942655 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128332070262843
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001577592 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128341225995987
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001627627 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128325341363555
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.00115782 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12832614305758
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000923827 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128327662046827
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000879248 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128327112388797
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000883689 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128347538964942
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000871953 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324496496758
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000878865 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324335593863
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001012551 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324706759283
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000890887 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324537222168
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001601002 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324584394807
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001148547 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.12832460883339
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.001124528 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324408750531
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000933576 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# rho = 25.55920486196296
# Average number of multiedges = 9.128324431639216
# Maximum number of multiedges = 25.55920486196296
# Time to build the tree and compute the stretch: elapsed time: 0.000923547 seconds
#
# The total size of the linked list data structure should be at most 9688
# The actual size is 1000
#
# nnz in U matrix: 381
# elapsed time: 0.207160713 seconds
# 0.207160713

# %%
t
# Out:
# 0.207160713

# %%
la = copy(x); b = copy(acc);
itercount
# Out:
# "hard graph"

# %%
@time f = augTreeSolver(la,tol=1e-6,maxits=Inf,maxtime=20,verbose=true)
# Out:
#   0.939301 seconds (1.49 M allocations: 299.196 MB, 16.82% gc time)
# f (generic function with 1 method)

# %%
@time x = f(b);
# Out:
# PCG stopped at maxtime.
# PCG stopped after: 2017 iterations with relative error 0.02642392873125351.
#  20.015755 seconds (50.69 k allocations: 10.828 GB, 7.17% gc time)

# %%
norm(la * x - b) / norm(b)
# Out:
# 0.026423928727888596

# %% [markdown]
# ### to save the graph

# %%
writeToFile("myfile.txt", la)
rhs = open("myRightHandSide.txt", "w")
for i in 1:length(b)
    print(rhs, b[i], " ")
end
close(rhs)
