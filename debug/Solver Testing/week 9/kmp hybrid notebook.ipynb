# %%
using Laplacians
# Out:
# objc[56751]: Class TKApplication is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[56751]: Class TKMenu is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[56751]: Class TKContentView is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[56751]: Class TKWindow is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.

# %%
include( "../../../src/garbageSolver.jl")
# Out:
# stretchSample (generic function with 1 method)

# %%
n = 50000;
a = chimera(n,23);
b = rand(n); b = b - mean(b);

# %%
@time f = KMPLapSolver(a, verbose=true, tol=1e-5, params = KMPparams(1/300,6,0.0,600,:akpw));
# Out:
# aveStretch : 18.544427986407598 fac : 18.544427986407598
# level 0. Dimension 50000 off-tree edges : 57385
#
#
#
# rho = 9.365408169903708
# Initial number of multiedges = 936672 . Nonzeros in a = 100380
# Average number of multiedges = 9.33126072360597
# Maximum number of multiedges = 9.365408169903708
# Time to build the tree and compute the stretch: elapsed time: 0.260896743 seconds
# From last checkpoint until 25000 we have elapsed time: 0.337794328 seconds
# From last checkpoint until 37500 we have elapsed time: 0.035317623 seconds
# From last checkpoint until 49999 we have elapsed time: 0.033665392 seconds
#
# The total size of the linked list data structure should be at most 2404933
# The actual size is 1079200
#
# nnz in U matrix: 100889
#
# Eps error: 1.0400609574449369
# Condition number: (0.0,0.0)
#
#  12.490310 seconds (22.84 M allocations: 1.116 GB, 3.85% gc time)

# %%
@time x = f(b);
# Out:
# Working on the 10th iteration
# Working on the 20th iteration
# PCG stopped after: 28 iterations with relative error 0.09930524767995265.
# Working on the 10th iteration
# Working on the 20th iteration
# Working on the 30th iteration
# Working on the 40th iteration
# PCG stopped after: 42 iterations with relative error 0.07949903122556154.
# Working on the 10th iteration
# Working on the 20th iteration
# Working on the 30th iteration
# PCG stopped after: 31 iterations with relative error 0.0949681587250193.
# Working on the 10th iteration
# Working on the 20th iteration
# Working on the 30th iteration
# PCG stopped after: 32 iterations with relative error 0.09744855329266211.
# Working on the 10th iteration
# Working on the 20th iteration
# Working on the 30th iteration
# Working on the 40th iteration
# PCG stopped after: 41 iterations with relative error 0.09000563979919356.
# Working on the 10th iteration
# Working on the 20th iteration
# Working on the 30th iteration
# ...

# %%
norm(lap(a) * x - b) / norm(b)
# Out:
# 9.860389845814622e-6
