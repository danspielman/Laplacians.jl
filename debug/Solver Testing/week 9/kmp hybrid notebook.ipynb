# %%
using Laplacians
# Out:
# objc[28264]: Class TKApplication is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[28264]: Class TKMenu is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[28264]: Class TKContentView is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[28264]: Class TKWindow is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.

# %%
include("../../../src/garbageSolver.jl")
# Out:
# stretchSample (generic function with 1 method)

# %%
n = 500000;
a = chimera(n,23);
b = rand(n); b = b - mean(b);

# %%
@time f = KMPLapSolver(a, verbose=true, tol=1e-1, params = KMPparams(1/200,4,0.0,600,:akpw));
# Out:
# aveStretch : 12.976284903989507 fac : 12.976284903989507
# level 0. Dimension 500000 off-tree edges : 446045
# level 1. Dimension 6167 off-tree edges : 2233
#
#
#
# rho = 609.2797323659198
# Initial number of multiedges = 7522168 . Nonzeros in a = 12346
# Average number of multiedges = 609.2797323659187
# Maximum number of multiedges = 609.2797323659198
# Time to build the tree and compute the stretch: elapsed time: 0.071287519 seconds
# From last checkpoint until 3084 we have elapsed time: 0.080834044 seconds
# From last checkpoint until 4626 we have elapsed time: 0.049020862 seconds
# From last checkpoint until 6166 we have elapsed time: 0.043491985 seconds
#
# The total size of the linked list data structure should be at most 11402327
# The actual size is 134000
#
# nnz in U matrix: 12515
#
# Eps error: -0.11655288189889479
# Condition number: (0.0,0.0)
#
#   4.967349 seconds (12.16 M allocations: 1.478 GB, 20.57% gc time)

# %%
@time x = f(b);
# Out:
# PCG stopped after: 1 iterations with relative error 0.06823790031826865.
# PCG stopped after: 1 iterations with relative error 0.09980116061733442.
# PCG stopped after: 2 iterations with relative error 0.012797802634752277.
# PCG stopped after: 1 iterations with relative error 0.0930793248847039.
# PCG stopped after: 1 iterations with relative error 0.08188739145103213.
# PCG stopped after: 1 iterations with relative error 0.04485378229962108.
# PCG stopped after: 1 iterations with relative error 0.08359032163145093.
# PCG stopped after: 2 iterations with relative error 0.011241404673483644.
# PCG stopped after: 1 iterations with relative error 0.09182376981980411.
# PCG stopped after: 2 iterations with relative error 0.005682190275352757.
# PCG stopped after: 1 iterations with relative error 0.0414675572484101.
# PCG stopped after: 1 iterations with relative error 0.0631825578029622.
# PCG stopped after: 2 iterations with relative error 0.010778088294661484.
# ...

# %%
norm(lap(a) * x - b) / norm(b)
# Out:
# 0.09967858302865511
