# %%
using Laplacians
# Out:
# objc[11161]: Class TKApplication is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[11161]: Class TKMenu is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[11161]: Class TKContentView is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[11161]: Class TKWindow is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.

# %%
include("../../../src/samplingJLSolver.jl")
# Out:
# checkError (generic function with 1 method)

# %%
n = 100000;
a = wtedChimera(n, 47);
d = ones(n)
b = rand(n); b = b - mean(b);
nnz(a)
# Out:
# 557380

# %%
@time f = samplingSolver(a, d, maxits=1000, maxtime=50, 
    eps = 0.5, sampConst = 0.02, beta = 1.0, 
    verbose=true, returnCN=false);
# Out:
# rho = 10.603814641553438
# Time to build the augTree and run JL : elapsed time: 230.332354469 seconds
# Sum of leverage scores: 99981.31637431016
#
# The size of the linked list data structure is 2156400
#
# nnz in U matrix: 1141344
# Preconditioner has 1141344 nonzeros
# Eps error: 1.3007811806972183
# Condition number: (0.0,0.0)
#
# 245.509090 seconds (114.30 M allocations: 135.506 GB, 7.80% gc time)

# %%
@time norm((lap(a) + spdiagm(d)) * f(b) - b) / norm(b)
# Out:
# PCG stopped after: 13 iterations with relative error 8.55169515316107e-7.
#   1.097889 seconds (10.43 M allocations: 271.688 MB, 12.04% gc time)
# 8.36922438737683e-7
