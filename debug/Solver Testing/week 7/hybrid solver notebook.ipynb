# %%
using Laplacians
# Out:
# objc[7336]: Class TKApplication is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[7336]: Class TKMenu is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[7336]: Class TKContentView is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.
# objc[7336]: Class TKWindow is implemented in both /Users/serbanstan/anaconda/lib/libtk8.5.dylib and /System/Library/Frameworks/Tk.framework/Versions/8.5/Tk. One of the two will be used. Which one is undefined.

# %%
include("../../../src/hybridSolver.jl")
# Out:
# stretchSample (generic function with 1 method)

# %%
n = 100000;
a = wtedChimera(n,1);
b = rand(n); b = b - mean(b);

# %%
@time f = KMPLapSolver(a, verbose=true, tol=1e-1);
# Out:
# aveStretch : 7.739207530005053 fac : 16.06818182880476
# level 0. Dimension 100000 off-tree edges : 280357
# level 1. Dimension 27252 off-tree edges : 11147
#
#
#
# rho = 8.344237013239727
# Initial number of multiedges = 454780 . Nonzeros in a = 55078
# Average number of multiedges = 8.257002055982829
# Maximum number of multiedges = 8.344237013239727
# Time to build the tree and compute the stretch: elapsed time: 0.116389547 seconds
#
# The total size of the linked list data structure should be at most 1227208
# The actual size is 671600
#
# nnz in U matrix: 54791
#
# Eps error: 0.003923068503907038
# Condition number: (0.0,0.0)
#
#   2.219581 seconds (10.48 M allocations: 785.214 MB, 17.87% gc time)

# %%
@time f(b);
# Out:
# PCG stopped after: 13 iterations with relative error 4.0661377470449344e-7.
# PCG stopped after: 13 iterations with relative error 4.109683607276141e-7.
# PCG stopped after: 13 iterations with relative error 6.282343667987049e-7.
# PCG stopped after: 13 iterations with relative error 5.443696994600302e-7.
# PCG stopped after: 13 iterations with relative error 5.533709388810799e-7.
# PCG stopped after: 13 iterations with relative error 3.279008435381941e-7.
# PCG stopped after: 13 iterations with relative error 5.136046032412872e-7.
# PCG stopped after: 13 iterations with relative error 9.697324845630447e-7.
# PCG stopped after: 13 iterations with relative error 5.26701783214561e-7.
# PCG stopped after: 13 iterations with relative error 6.814641447702983e-7.
# PCG stopped after: 13 iterations with relative error 4.847297683167566e-7.
# PCG stopped after: 13 iterations with relative error 3.1162553966464193e-7.
# ...
