# %% [markdown]
# # The following is are examples of using Laplacians/primalDualIPM for flow problems

# %%
using Laplacians
include("/Users/spielman/Laplacians/src/min_cost_flow.jl")
include("/Users/spielman/Laplacians/src/primalDualIPM.jl")
include("/Users/spielman/Laplacians/src/max_flow_IPM.jl")
include("/Users/spielman/Laplacians/src/flowUtils.jl")
# Out:
# WARNING: Method definition min_cost_flow(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main at /Users/spielman/Laplacians/src/min_cost_flow.jl:19 overwritten at /Users/spielman/Laplacians/src/min_cost_flow.jl:19.
# WARNING: Method definition #min_cost_flow(Array{Any, 1}, Main.#min_cost_flow, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main overwritten.
# WARNING: Method definition ipm_directions_min_cost_flow(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Integer) in module Main at /Users/spielman/Laplacians/src/min_cost_flow.jl:120 overwritten at /Users/spielman/Laplacians/src/min_cost_flow.jl:120.
# WARNING: Method definition #ipm_directions_min_cost_flow(Array{Any, 1}, Main.#ipm_directions_min_cost_flow, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Integer) in module Main overwritten.
# WARNING: Method definition ipm_min_cost_flow_initial_point(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Integer, Integer) in module Main at /Users/spielman/Laplacians/src/min_cost_flow.jl:168 overwritten at /Users/spielman/Laplacians/src/min_cost_flow.jl:168.
# WARNING: Method definition #ipm_min_cost_flow_initial_point(Array{Any, 1}, Main.#ipm_min_cost_flow_initial_point, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Integer, Integer) in module Main overwritten.
# WARNING: Method definition calstepsize(Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main at /Users/spielman/Laplacians/src/min_cost_flow.jl:213 overwritten at /Users/spielman/Laplacians/src/min_cost_flow.jl:213.
# WARNING: Method definition calstepsize(Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Float64) in module Main at /Users/spielman/Laplacians/src/min_cost_flow.jl:213 overwritten at /Users/spielman/Laplacians/src/min_cost_flow.jl:213.
# WARNING: Method definition minCostFlow(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:15 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:15.
# WARNING: Method definition #minCostFlow(Array{Any, 1}, Main.#minCostFlow, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main overwritten.
# WARNING: Method definition primalDualIPM(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:37 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:37.
# WARNING: Method definition #primalDualIPM(Array{Any, 1}, Main.#primalDualIPM, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any) in module Main overwritten.
# WARNING: Method definition initialPoint(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:131 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:131.
# WARNING: Method definition initialPoint1(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:158 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:158.
# WARNING: Method definition solver1(Any, Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:183 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:183.
# WARNING: Method definition solver2(Any, Any, Any, Any, Any, Any, Any, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:203 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:203.
# WARNING: Method definition solver3(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:228 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:228.
# WARNING: Method definition shurSolve(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Integer, Integer, Any) in module Main at /Users/spielman/Laplacians/src/primalDualIPM.jl:248 overwritten at /Users/spielman/Laplacians/src/primalDualIPM.jl:248.
# WARNING: Method definition max_flow_IPM(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main at /Users/spielman/Laplacians/src/max_flow_IPM.jl:17 overwritten at /Users/spielman/Laplacians/src/max_flow_IPM.jl:17.
# WARNING: Method definition #max_flow_IPM(Array{Any, 1}, Main.#max_flow_IPM, Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main overwritten.
# WARNING: Method definition ipm_max_flow_step_length(Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}) in module Main at /Users/spielman/Laplacians/src/max_flow_IPM.jl:94 overwritten at /Users/spielman/Laplacians/src/max_flow_IPM.jl:94.
# WARNING: Method definition ipm_max_flow_step_length(Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Float64) in module Main at /Users/spielman/Laplacians/src/max_flow_IPM.jl:94 overwritten at /Users/spielman/Laplacians/src/max_flow_IPM.jl:94.
# WARNING: Method definition ipm_max_flow_initial_point(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any, Any, Any) in module Main at /Users/spielman/Laplacians/src/max_flow_IPM.jl:117 overwritten at /Users/spielman/Laplacians/src/max_flow_IPM.jl:117.
# WARNING: Method definition ipm_max_flow_solver(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Any) in module Main at /Users/spielman/Laplacians/src/max_flow_IPM.jl:159 overwritten at /Users/spielman/Laplacians/src/max_flow_IPM.jl:159.
# WARNING: Method definition ipm_max_flow_shur_solve(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Array{#Tv<:Any, 1}, Integer, Integer, Function) in module Main at /Users/spielman/Laplacians/src/max_flow_IPM.jl:181 overwritten at /Users/spielman/Laplacians/src/max_flow_IPM.jl:181.
# WARNING: Method definition makeSTFlowProblem(Any) in module Main at /Users/spielman/Laplacians/src/flowUtils.jl:4 overwritten at /Users/spielman/Laplacians/src/flowUtils.jl:4.
# WARNING: Method definition #makeSTFlowProblem(Array{Any, 1}, Main.#makeSTFlowProblem, Any) in module Main overwritten.
# WARNING: Method definition stFlow(Any, Any, Any) in module Main at /Users/spielman/Laplacians/src/flowUtils.jl:44 overwritten at /Users/spielman/Laplacians/src/flowUtils.jl:44.
# WARNING: Method definition #stFlow(Array{Any, 1}, Main.#stFlow, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition reachFrom(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, #Ti<:Any) in module Main at /Users/spielman/Laplacians/src/flowUtils.jl:94 overwritten at /Users/spielman/Laplacians/src/flowUtils.jl:94.
# WARNING: Method definition cutCapacity(Base.SparseArrays.SparseMatrixCSC{#Tv<:Any, #Ti<:Any}, Array{#Ti<:Any, 1}) in module Main at /Users/spielman/Laplacians/src/flowUtils.jl:137 overwritten at /Users/spielman/Laplacians/src/flowUtils.jl:137.
# cutCapacity

# %% [markdown]
# ## First, we try some max flow problems.
# This code generates some, and then calls max_flow_IPM.
# We will start small.

# %%
n = 100
a = chimera(n,1);
af,s,t = makeSTFlowProblem(a)
fl = stFlow(af,s,t);
# Out:
# size(Bt) = (102,396)
# Ratio of edge weights: 1.0
# Iteration 1, ||r_p||=63.635231, ||r_d||=14.726782, mu=1.235272
# Ratio of edge weights: 3.517153857092042
# sigma parameter is 0.13303917704244886
# Iteration 2, ||r_p||=0.636352, ||r_d||=3.530600, mu=0.548329
# Ratio of edge weights: 32.57177259857809
# sigma parameter is 1.7951541493146115e-6
# Iteration 3, ||r_p||=0.006364, ||r_d||=0.035306, mu=0.005497
# Ratio of edge weights: 27.946566721935348
# sigma parameter is 0.17360746099270727
# Iteration 4, ||r_p||=0.000064, ||r_d||=0.002808, mu=0.001312
# Ratio of edge weights: 595.8061504586377
# sigma parameter is 0.05445096229748747
# Iteration 5, ||r_p||=0.000013, ||r_d||=0.000415, mu=0.000259
# Ratio of edge weights: 183939.96060825256
# sigma parameter is 0.021582662931177308
# Iteration 6, ||r_p||=0.000001, ||r_d||=0.000059, mu=0.000041
# Ratio of edge weights: 5.132822274923839e7
# sigma parameter is 0.0011419904911829245
# Iteration 7, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000001
# Termination tolerance reached.
#
# The error in satisfying the demand is 8.40906161904656e-9
# The flow value is 7.99863544501122
# The cut value is 8.0

# %% [markdown]
# Now, let's try a weighted graph.

# %%
n = 100
a = wtedChimera(n,1);
af,s,t = makeSTFlowProblem(a)
fl = stFlow(af,s,t);
# Out:
# size(Bt) = (102,396)
# Ratio of edge weights: 1.0
# Iteration 1, ||r_p||=1426.380367, ||r_d||=287.454810, mu=81.136838
# Ratio of edge weights: 162.45982209158493
# sigma parameter is 0.5496894795824239
# Iteration 2, ||r_p||=1225.714671, ||r_d||=215.090875, mu=80.285022
# Ratio of edge weights: 66105.1351595706
# sigma parameter is 0.26759509789060204
# Iteration 3, ||r_p||=454.807757, ||r_d||=79.894332, mu=46.564543
# Ratio of edge weights: 3559.3573648212396
# sigma parameter is 0.11973211223177334
# Iteration 4, ||r_p||=116.762929, ||r_d||=7.348468, mu=12.416308
# Ratio of edge weights: 19645.86693280167
# sigma parameter is 0.06810841630934861
# Iteration 5, ||r_p||=1.167629, ||r_d||=0.647778, mu=2.048510
# Ratio of edge weights: 6549.513979529065
# sigma parameter is 4.523184885344383e-5
# Iteration 6, ||r_p||=0.099771, ||r_d||=0.013154, mu=0.041790
# Ratio of edge weights: 6900.899938439309
# sigma parameter is 0.00026565770010078196
# Iteration 7, ||r_p||=0.000998, ||r_d||=0.000661, mu=0.002109
# Ratio of edge weights: 6930.030251027448
# sigma parameter is 0.9427712983608365
# Iteration 8, ||r_p||=0.000810, ||r_d||=0.000465, mu=0.002090
# Ratio of edge weights: 298940.1098045544
# sigma parameter is 0.009601929840077827
# Iteration 9, ||r_p||=0.000008, ||r_d||=0.000078, mu=0.000365
# Ratio of edge weights: 367205.16760177363
# sigma parameter is 0.07122973413600557
# Iteration 10, ||r_p||=0.000003, ||r_d||=0.000005, mu=0.000061
# Ratio of edge weights: 2.1246896499964453e7
# sigma parameter is 0.006742940135048769
# Iteration 11, ||r_p||=0.000001, ||r_d||=0.000000, mu=0.000003
# Ratio of edge weights: 1.0903873805850376e10
# sigma parameter is 0.001606015858513564
# Iteration 12, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000000
# Termination tolerance reached.
#
# The error in satisfying the demand is 2.7493734658323244e-8
# The flow value is 5.750221387270357
# The cut value is 5.855699283557031

# %% [markdown]
# The gap between the flow and cut above should be a bit of a concern.
# It could be due to our crude heuristic for computing the cut.
# But, below we see that there is flow out of t, which I don't think should happen.

# %%
f = fl[3]
(afi,afj) = findnz(af)
@show sum(f[afj.==t])
@show sum(f[afi.==t])
# Out:
# sum(f[afj .== t]) = 12.134818765108266
# sum(f[afi .== t]) = 17.885040153054387
# 17.885040153054387

# %% [markdown]
# Let's try a much larger unweighed graph.  We seem to do better with the unweighted ones. We might need to use a better solver.  By default, the code so far was using cholesky, which can be slow.

# %%
n = 10000
a = chimera(n,1);
af,s,t = makeSTFlowProblem(a)
#fl = stFlow(af,s,t,tol=1e-6,lapSolver = (h->augTreeLap(h,tol=1e-6)));
fl = stFlow(af,s,t,tol=1e-6);
# Out:
# size(Bt) = (10002,51440)
# Ratio of edge weights: 1.0
# Iteration 1, ||r_p||=508.827755, ||r_d||=96.668490, mu=0.715187
# Ratio of edge weights: 1.0000189769883967
# sigma parameter is 0.01122574491220749
# Iteration 2, ||r_p||=5.088278, ||r_d||=0.966685, mu=0.066342
# Ratio of edge weights: 15.747162877799266
# sigma parameter is 3.8968149502740955e-6
# Iteration 3, ||r_p||=0.050883, ||r_d||=0.009667, mu=0.000662
# Ratio of edge weights: 15.908080576054914
# sigma parameter is 0.41108679484326427
# Iteration 4, ||r_p||=0.000509, ||r_d||=0.005604, mu=0.000498
# Ratio of edge weights: 19.850198902017333
# sigma parameter is 0.28023057338185947
# Iteration 5, ||r_p||=0.000005, ||r_d||=0.000056, mu=0.000143
# Ratio of edge weights: 107.17360006347366
# sigma parameter is 0.17902105367615506
# Iteration 6, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000027
# Ratio of edge weights: 519890.14570793277
# sigma parameter is 0.11656530241121132
# Iteration 7, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000009
# Ratio of edge weights: 433188.1151843112
# sigma parameter is 0.01117228769714228
# Iteration 8, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000003
# Ratio of edge weights: 2.851362075587094e7
# sigma parameter is 0.010286795613738485
# Iteration 9, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000000
# Termination tolerance reached.
#
# The error in satisfying the demand is 1.9298155701347036e-9
# The flow value is 97.63261564362912
# The cut value is 98.0

# %% [markdown]
# This worked, but it is very finnicky.  Using a lower tol can cause it to die.  This is probably because the ratio of the edge weights grows huge.  The following is an example on which it dies.

# %%
fl = stFlow(af,s,t,tol=1e-8);
# Out:
# size(Bt) = (10002,51440)
# Ratio of edge weights: 1.0
# Iteration 1, ||r_p||=508.827755, ||r_d||=96.668490, mu=0.715187
# Ratio of edge weights: 1.0000189769883967
# sigma parameter is 0.01122574491220749
# Iteration 2, ||r_p||=5.088278, ||r_d||=0.966685, mu=0.066342
# Ratio of edge weights: 15.747162877799266
# sigma parameter is 3.8968149502740955e-6
# Iteration 3, ||r_p||=0.050883, ||r_d||=0.009667, mu=0.000662
# Ratio of edge weights: 15.908080576054914
# sigma parameter is 0.41108679484326427
# Iteration 4, ||r_p||=0.000509, ||r_d||=0.005604, mu=0.000498
# Ratio of edge weights: 19.850198902017333
# sigma parameter is 0.28023057338185947
# Iteration 5, ||r_p||=0.000005, ||r_d||=0.000056, mu=0.000143
# Ratio of edge weights: 107.17360006347366
# sigma parameter is 0.17902105367615506
# Iteration 6, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000027
# Ratio of edge weights: 519890.14570793277
# sigma parameter is 0.11656530241121132
# Iteration 7, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000009
# Ratio of edge weights: 433188.1151843112
# sigma parameter is 0.01117228769714228
# Iteration 8, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000003
# Ratio of edge weights: 2.851362075587094e7
# sigma parameter is 0.010286795613738485
# Iteration 9, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000000
# Ratio of edge weights: 1.3402148092837112e9
# sigma parameter is 2.9222760646171645e-5
# Iteration 10, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000000
# Ratio of edge weights: 1.353542692170215e13
# sigma parameter is 1.0000004976249218e-6
# Iteration 11, ||r_p||=0.000466, ||r_d||=0.000000, mu=0.000000
# Ratio of edge weights: 1.3531423622614806e17
# sigma parameter is 0.0019620136039383094
# Iteration 12, ||r_p||=10.704513, ||r_d||=0.000000, mu=0.000000
# Ratio of edge weights: 6.7429741668475585e19
# Base.LinAlg.PosDefException(10000)
#
#  in #cholfact!#6(::Float64, ::Function, ::Base.SparseArrays.CHOLMOD.Factor{Float64}, ::Base.SparseArrays.CHOLMOD.Sparse{Float64}) at ./sparse/cholmod.jl:1255
#  in (::Base.LinAlg.#kw##cholfact!)(::Array{Any,1}, ::Base.LinAlg.#cholfact!, ::Base.SparseArrays.CHOLMOD.Factor{Float64}, ::Base.SparseArrays.CHOLMOD.Sparse{Float64}) at ./<missing>:0
#  in #cholfact#8(::Float64, ::Array{Int64,1}, ::Function, ::Base.SparseArrays.CHOLMOD.Sparse{Float64}) at ./sparse/cholmod.jl:1291
#  in #cholfact#9(::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./sparse/cholmod.jl:1330
#  in #wrapInterface#78(::Int64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::Base.LinAlg.#cholfact, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:36
#  in (::Laplacians.#kw##wrapInterface)(::Array{Any,1}, ::Laplacians.#wrapInterface, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in (::Laplacians.###83#84#86{Base.LinAlg.#cholfact})(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:64
#  in (::Laplacians.#kw###83#85)(::Array{Any,1}, ::Laplacians.##83#85, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in #lapWrapConnected#87(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:113
#  in (::Laplacians.#kw##lapWrapConnected)(::Array{Any,1}, ::Laplacians.#lapWrapConnected, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in (::Laplacians.##f#92#94{Laplacians.##83#85})(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:137
#  in (::Laplacians.#kw##f#93)(::Array{Any,1}, ::Laplacians.#f#93, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in #lapWrapComponents#100(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:194
#  in (::Laplacians.#kw##lapWrapComponents)(::Array{Any,1}, ::Laplacians.#lapWrapComponents, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in (::Laplacians.##f#103#105{Laplacians.#f#93})(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:237
#  in (::Laplacians.#f#104)(::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:237
#  in ipm_max_flow_shur_solve(::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64, ::Int64, ::Laplacians.#f#104) at /Users/spielman/Laplacians/src/max_flow_IPM.jl:205
#  in (::##58#61{Laplacians.#f#104,SparseMatrixCSC{Float64,Int64},Array{Float64,1},Int64,Int64})(::Array{Float64,1}, ::Array{Float64,1}) at /Users/spielman/Laplacians/src/max_flow_IPM.jl:29
#  in #max_flow_IPM#56(::Function, ::Float64, ::Function, ::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/spielman/Laplacians/src/max_flow_IPM.jl:56
#  in (::#kw##max_flow_IPM)(::Array{Any,1}, ::#max_flow_IPM, ::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}) at ./<missing>:0
#  in #stFlow#65(::Function, ::Float64, ::Function, ::SparseMatrixCSC{Float64,Int64}, ::Int64, ::Int64) at /Users/spielman/Laplacians/src/flowUtils.jl:58
#  in (::#kw##stFlow)(::Array{Any,1}, ::#stFlow, ::SparseMatrixCSC{Float64,Int64}, ::Int64, ::Int64) at ./<missing>:0

# %% [markdown]
# Now, let's compare our answer with the one given by our other maxflow code.

# %%
chf = Laplacians.maxflow(af,s,t)
# Out:
# 98.0

# %% [markdown]
# ## Now, let's try testing the min cost flow code.
# I don't have any other code that computes this, so I won't know if the answer is correct.
# But, at least we can get some timings.

# %%
n = 100
a = chimera(n,1)

Bt= -dirEdgeVertexMat(a)';
m = nnz(a)

c = rand(m);
b = 0.25*Bt*rand(m);
u = 0.25*ones(m);

# %%
@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = cholLap);
# Out:
# Iteration 1, ||r_p||=1.806108, ||r_d||=31.920958, mu=0.687489
# Iteration 2, ||r_p||=0.622969, ||r_d||=11.010282, mu=0.438648
# Iteration 3, ||r_p||=0.130696, ||r_d||=2.309908, mu=0.102424
# Iteration 4, ||r_p||=0.039113, ||r_d||=0.691285, mu=0.045795
# Iteration 5, ||r_p||=0.008959, ||r_d||=0.158333, mu=0.012627
# Iteration 6, ||r_p||=0.002263, ||r_d||=0.039992, mu=0.005137
# Iteration 7, ||r_p||=0.000119, ||r_d||=0.002111, mu=0.001967
# Iteration 8, ||r_p||=0.000019, ||r_d||=0.000331, mu=0.000554
# Iteration 9, ||r_p||=0.000003, ||r_d||=0.000046, mu=0.000161
# Iteration 10, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000041
# Iteration 11, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000007
# Iteration 12, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000000
# Termination tolerance reached.
#   0.118599 seconds (33.48 k allocations: 10.960 MB)

# %% [markdown]
# Let's run on a much larger example

# %%
n = 10000
a = chimera(n,1)

Bt= -dirEdgeVertexMat(a)';
m = nnz(a)

c = rand(m);
b = 0.25*Bt*rand(m);
u = 0.25*ones(m);

@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = cholLap);
# Out:
# Iteration 1, ||r_p||=22.992661, ||r_d||=408.282072, mu=0.777585
# Iteration 2, ||r_p||=10.735538, ||r_d||=190.631589, mu=0.590004
# Iteration 3, ||r_p||=2.344975, ||r_d||=41.639870, mu=0.153289
# Iteration 4, ||r_p||=0.646444, ||r_d||=11.478952, mu=0.069290
# Iteration 5, ||r_p||=0.163679, ||r_d||=2.906466, mu=0.023968
# Iteration 6, ||r_p||=0.038889, ||r_d||=0.690546, mu=0.009859
# Iteration 7, ||r_p||=0.005667, ||r_d||=0.100622, mu=0.004606
# Iteration 8, ||r_p||=0.001283, ||r_d||=0.022791, mu=0.001969
# Iteration 9, ||r_p||=0.000186, ||r_d||=0.003297, mu=0.000869
# Iteration 10, ||r_p||=0.000027, ||r_d||=0.000485, mu=0.000282
# Iteration 11, ||r_p||=0.000007, ||r_d||=0.000117, mu=0.000137
# Iteration 12, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000060
# Iteration 13, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000024
# Iteration 14, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000010
# Iteration 15, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000003
# Iteration 16, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Iteration 17, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Termination tolerance reached.
#  10.465217 seconds (1.98 M allocations: 1.988 GB, 8.03% gc time)

# %% [markdown]
# Now, let's see what happens when we try different solvers.
# If you are running this, be sure to run twice, as it compiles the first time.

# %%
@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = augTreeLap);
# Out:
# Iteration 1, ||r_p||=22.992661, ||r_d||=408.282072, mu=0.777585
# Iteration 2, ||r_p||=10.735542, ||r_d||=190.631672, mu=0.590004
# Iteration 3, ||r_p||=2.344979, ||r_d||=41.639928, mu=0.153289
# Iteration 4, ||r_p||=0.646445, ||r_d||=11.478973, mu=0.069290
# Iteration 5, ||r_p||=0.163679, ||r_d||=2.906470, mu=0.023968
# Iteration 6, ||r_p||=0.038888, ||r_d||=0.690547, mu=0.009859
# Iteration 7, ||r_p||=0.005667, ||r_d||=0.100622, mu=0.004606
# Iteration 8, ||r_p||=0.001283, ||r_d||=0.022791, mu=0.001969
# Iteration 9, ||r_p||=0.000186, ||r_d||=0.003297, mu=0.000869
# Iteration 10, ||r_p||=0.000027, ||r_d||=0.000485, mu=0.000282
# Iteration 11, ||r_p||=0.000007, ||r_d||=0.000117, mu=0.000137
# Iteration 12, ||r_p||=0.000002, ||r_d||=0.000001, mu=0.000060
# Iteration 13, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000024
# Iteration 14, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000010
# Iteration 15, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000003
# Iteration 16, ||r_p||=0.000001, ||r_d||=0.000000, mu=0.000001
# Iteration 17, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Termination tolerance reached.
#  15.437320 seconds (12.52 M allocations: 4.129 GB, 15.77% gc time)

# %%
@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = (h->KMPLapSolver(h,tol=1e-8)));
# Out:
# Iteration 1, ||r_p||=22.992661, ||r_d||=408.282072, mu=0.777585
# Iteration 2, ||r_p||=10.735538, ||r_d||=190.631589, mu=0.590004
# Iteration 3, ||r_p||=2.344975, ||r_d||=41.639869, mu=0.153289
# Iteration 4, ||r_p||=0.646444, ||r_d||=11.478951, mu=0.069290
# Iteration 5, ||r_p||=0.163679, ||r_d||=2.906466, mu=0.023968
# Iteration 6, ||r_p||=0.038889, ||r_d||=0.690546, mu=0.009859
# Iteration 7, ||r_p||=0.005667, ||r_d||=0.100622, mu=0.004606
# Iteration 8, ||r_p||=0.001283, ||r_d||=0.022791, mu=0.001969
# Iteration 9, ||r_p||=0.000186, ||r_d||=0.003297, mu=0.000869
# Iteration 10, ||r_p||=0.000027, ||r_d||=0.000485, mu=0.000282
# Iteration 11, ||r_p||=0.000007, ||r_d||=0.000117, mu=0.000137
# Iteration 12, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000060
# Iteration 13, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000024
# Iteration 14, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000010
# Iteration 15, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000003
# Iteration 16, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Iteration 17, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Termination tolerance reached.
#  17.566913 seconds (13.36 M allocations: 7.924 GB, 14.39% gc time)

# %% [markdown]
# Note that if I ran that with a lower tolerance on the solve, then we have trouble with the convergence of the IPM.

# %%
n = 50000
a = chimera(n,1)

Bt= -dirEdgeVertexMat(a)';
m = nnz(a)

c = rand(m);
b = 0.25*Bt*rand(m);
u = 0.25*ones(m);

@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = augTreeLap);
# Out:
# Iteration 1, ||r_p||=45.808803, ||r_d||=826.954312, mu=0.804767
# Iteration 2, ||r_p||=24.810425, ||r_d||=447.885279, mu=0.664281
# Iteration 3, ||r_p||=3.519400, ||r_d||=63.533277, mu=0.166916
# Iteration 4, ||r_p||=0.901392, ||r_d||=16.272197, mu=0.071359
# Iteration 5, ||r_p||=0.218615, ||r_d||=3.946510, mu=0.026210
# Iteration 6, ||r_p||=0.052552, ||r_d||=0.948694, mu=0.011219
# Iteration 7, ||r_p||=0.010869, ||r_d||=0.196206, mu=0.005185
# Iteration 8, ||r_p||=0.002098, ||r_d||=0.037867, mu=0.002788
# Iteration 9, ||r_p||=0.000119, ||r_d||=0.002149, mu=0.001118
# Iteration 10, ||r_p||=0.000016, ||r_d||=0.000265, mu=0.000459
# Iteration 11, ||r_p||=0.000004, ||r_d||=0.000035, mu=0.000275
# Iteration 12, ||r_p||=0.000005, ||r_d||=0.000011, mu=0.000112
# Iteration 13, ||r_p||=0.000005, ||r_d||=0.000001, mu=0.000050
# Iteration 14, ||r_p||=0.000005, ||r_d||=0.000000, mu=0.000022
# Iteration 15, ||r_p||=0.000004, ||r_d||=0.000000, mu=0.000010
# Iteration 16, ||r_p||=0.000005, ||r_d||=0.000000, mu=0.000004
# Iteration 17, ||r_p||=0.000005, ||r_d||=0.000000, mu=0.000002
# Iteration 18, ||r_p||=0.000004, ||r_d||=0.000000, mu=0.000001
# Iteration 19, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000000
# Termination tolerance reached.
# 140.537517 seconds (59.08 M allocations: 23.752 GB, 10.35% gc time)

# %%
@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = (h->KMPLapSolver(h,tol=1e-8)));
# Out:
# Iteration 1, ||r_p||=45.808803, ||r_d||=826.954312, mu=0.804767
# Iteration 2, ||r_p||=24.810426, ||r_d||=447.885281, mu=0.664281
# Iteration 3, ||r_p||=3.519378, ||r_d||=63.532867, mu=0.166915
# Iteration 4, ||r_p||=0.901387, ||r_d||=16.272114, mu=0.071359
# Iteration 5, ||r_p||=0.218614, ||r_d||=3.946492, mu=0.026210
# Iteration 6, ||r_p||=0.052552, ||r_d||=0.948689, mu=0.011219
# Iteration 7, ||r_p||=0.010869, ||r_d||=0.196205, mu=0.005185
# Iteration 8, ||r_p||=0.002098, ||r_d||=0.037867, mu=0.002788
# Iteration 9, ||r_p||=0.000119, ||r_d||=0.002149, mu=0.001118
# Iteration 10, ||r_p||=0.000015, ||r_d||=0.000265, mu=0.000459
# Iteration 11, ||r_p||=0.000002, ||r_d||=0.000035, mu=0.000275
# Iteration 12, ||r_p||=0.000001, ||r_d||=0.000011, mu=0.000112
# Iteration 13, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000050
# Iteration 14, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000022
# Iteration 15, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000010
# Iteration 16, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000004
# Iteration 17, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000002
# Iteration 18, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Termination tolerance reached.
# 156.525575 seconds (60.09 M allocations: 47.769 GB, 10.57% gc time)

# %%
@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = cholLap);
# Out:
# Iteration 1, ||r_p||=45.808803, ||r_d||=826.954312, mu=0.804767
# Iteration 2, ||r_p||=24.810426, ||r_d||=447.885281, mu=0.664281
# InterruptException:
#
#  in analyze(::Base.SparseArrays.CHOLMOD.Sparse{Float64}, ::Array{UInt8,1}) at ./sparse/cholmod.jl:723
#  in #fact_#3(::Array{Int64,1}, ::Bool, ::Bool, ::Function, ::Base.SparseArrays.CHOLMOD.Sparse{Float64}, ::Array{UInt8,1}) at ./sparse/cholmod.jl:1234
#  in (::Base.SparseArrays.CHOLMOD.#kw##fact_)(::Array{Any,1}, ::Base.SparseArrays.CHOLMOD.#fact_, ::Base.SparseArrays.CHOLMOD.Sparse{Float64}, ::Array{UInt8,1}) at ./<missing>:0
#  in #cholfact#8(::Float64, ::Array{Int64,1}, ::Function, ::Base.SparseArrays.CHOLMOD.Sparse{Float64}) at ./sparse/cholmod.jl:1288
#  in #cholfact#9(::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./sparse/cholmod.jl:1330
#  in #wrapInterface#78(::Int64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::Base.LinAlg.#cholfact, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:36
#  in (::Laplacians.#kw##wrapInterface)(::Array{Any,1}, ::Laplacians.#wrapInterface, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in (::Laplacians.###83#84#86{Base.LinAlg.#cholfact})(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:64
#  in (::Laplacians.#kw###83#85)(::Array{Any,1}, ::Laplacians.##83#85, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in #lapWrapConnected#87(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:113
#  in (::Laplacians.#kw##lapWrapConnected)(::Array{Any,1}, ::Laplacians.#lapWrapConnected, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in (::Laplacians.##f#92#94{Laplacians.##83#85})(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:137
#  in (::Laplacians.#kw##f#93)(::Array{Any,1}, ::Laplacians.#f#93, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in #lapWrapComponents#100(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:194
#  in (::Laplacians.#kw##lapWrapComponents)(::Array{Any,1}, ::Laplacians.#lapWrapComponents, ::Function, ::SparseMatrixCSC{Float64,Int64}) at ./<missing>:0
#  in (::Laplacians.##f#103#105{Laplacians.#f#93})(::Float64, ::Float64, ::Float64, ::Bool, ::Array{Int64,1}, ::Array{Any,1}, ::Function, ::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:237
#  in (::Laplacians.#f#104)(::SparseMatrixCSC{Float64,Int64}) at /Users/spielman/.julia/v0.5/Laplacians/src/solverInterface.jl:237
#  in #ipm_directions_min_cost_flow#49(::Laplacians.#f#104, ::Function, ::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64) at /Users/spielman/Laplacians/src/min_cost_flow.jl:128
#  in (::#kw##ipm_directions_min_cost_flow)(::Array{Any,1}, ::#ipm_directions_min_cost_flow, ::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Int64) at ./<missing>:0
#  in #min_cost_flow#48(::Function, ::Float64, ::Function, ::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/spielman/Laplacians/src/min_cost_flow.jl:88
#  in (::#kw##min_cost_flow)(::Array{Any,1}, ::#min_cost_flow, ::SparseMatrixCSC{Float64,Int64}, ::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}) at ./<missing>:0

# %% [markdown]
# I stopped that code, because it was taking forever.

# %% [markdown]
# ## Matlab connection

# %% [markdown]
# Finally, I note that if you are have Matlab, and can install Koutis's KMP solvers so that they run from Matlab, then you can also call them from Julia.  The only annoying thing about them is that they spit out a lot of diagonstics. To use them, you need to get the MATLAB.jl package working.  Then, you can use the matlab solvers like this:

# %%
include("/Users/spielman/Laplacians/src/matlabSolvers.jl")
# Out:
# >> >> >> Connected to Matlab!
# matlabCmgLap

# %%
@time (x_ntipm_flow,s,y) = min_cost_flow(Bt',c,b,u, lapSolver = (h->matlabCmgLap(h,tol=1e-8)));
# Out:
# Iteration 1, ||r_p||=45.808803, ||r_d||=826.954312, mu=0.804767
# >> >> >>
#
# Level 2. Graph vertices: 14200
# Density : 10.037
# Reduction factor in vertices : 3.52106
# Reduction factor in edges    : 1.75383
# *****************
# Level 3. Graph vertices: 5489
# Density : 21.153
# Reduction factor in vertices : 2.58699
# Reduction factor in edges    : 1.22752
# *****************
# Level 4. Graph vertices: 4736
# Density : 24.0025
# Reduction factor in vertices : 1.15899
# Reduction factor in edges    : 1.0214
# *****************
# Level 5. Graph vertices: 4638
# Density : 24.4299
# Reduction factor in vertices : 1.02113
# Reduction factor in edges    : 1.00327
# *****************
# Level 6. Graph vertices: 4609
# Density : 24.557
# Reduction factor in vertices : 1.00629
# Reduction factor in edges    : 1.00109
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.170000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14200
# Density : 10.037
# Reduction factor in vertices : 3.52106
# Reduction factor in edges    : 1.75383
# *****************
# Level 3. Graph vertices: 5489
# Density : 21.153
# Reduction factor in vertices : 2.58699
# Reduction factor in edges    : 1.22752
# *****************
# Level 4. Graph vertices: 4736
# Density : 24.0025
# Reduction factor in vertices : 1.15899
# Reduction factor in edges    : 1.0214
# *****************
# Level 5. Graph vertices: 4638
# Density : 24.4299
# Reduction factor in vertices : 1.02113
# Reduction factor in edges    : 1.00327
# *****************
# Level 6. Graph vertices: 4609
# Density : 24.557
# Reduction factor in vertices : 1.00629
# Reduction factor in edges    : 1.00109
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.100000 seconds
# Iteration 2, ||r_p||=24.810426, ||r_d||=447.885279, mu=0.664281
# >> >> >>
#
# Level 2. Graph vertices: 13809
# Density : 10.2341
# Reduction factor in vertices : 3.62075
# Reduction factor in edges    : 1.76876
# *****************
# Level 3. Graph vertices: 5079
# Density : 22.5987
# Reduction factor in vertices : 2.71884
# Reduction factor in edges    : 1.23126
# *****************
# Level 4. Graph vertices: 4437
# Density : 25.4021
# Reduction factor in vertices : 1.14469
# Reduction factor in edges    : 1.01837
# *****************
# Level 5. Graph vertices: 4356
# Density : 25.803
# Reduction factor in vertices : 1.0186
# Reduction factor in edges    : 1.00277
# *****************
# Level 6. Graph vertices: 4337
# Density : 25.8955
# Reduction factor in vertices : 1.00438
# Reduction factor in edges    : 1.00079
# *****************
# Level 7. Graph vertices: 4326
# Density : 25.9464
# Reduction factor in vertices : 1.00254
# Reduction factor in edges    : 1.00058
# *****************
# Level 8. Graph vertices: 4322
# Density : 25.9634
# Reduction factor in vertices : 1.00093
# Reduction factor in edges    : 1.00027
# *****************
# Level 9. Graph vertices: 4320
# Density : 25.9736
# Reduction factor in vertices : 1.00046
# Reduction factor in edges    : 1.00007
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.120000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 13809
# Density : 10.2341
# Reduction factor in vertices : 3.62075
# Reduction factor in edges    : 1.76876
# *****************
# Level 3. Graph vertices: 5079
# Density : 22.5987
# Reduction factor in vertices : 2.71884
# Reduction factor in edges    : 1.23126
# *****************
# Level 4. Graph vertices: 4437
# Density : 25.4021
# Reduction factor in vertices : 1.14469
# Reduction factor in edges    : 1.01837
# *****************
# Level 5. Graph vertices: 4356
# Density : 25.803
# Reduction factor in vertices : 1.0186
# Reduction factor in edges    : 1.00277
# *****************
# Level 6. Graph vertices: 4337
# Density : 25.8955
# Reduction factor in vertices : 1.00438
# Reduction factor in edges    : 1.00079
# *****************
# Level 7. Graph vertices: 4326
# Density : 25.9464
# Reduction factor in vertices : 1.00254
# Reduction factor in edges    : 1.00058
# *****************
# Level 8. Graph vertices: 4322
# Density : 25.9634
# Reduction factor in vertices : 1.00093
# Reduction factor in edges    : 1.00027
# *****************
# Level 9. Graph vertices: 4320
# Density : 25.9736
# Reduction factor in vertices : 1.00046
# Reduction factor in edges    : 1.00007
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.170000 seconds
# Iteration 3, ||r_p||=3.519378, ||r_d||=63.532865, mu=0.166915
# >> >> >>
#
# Level 2. Graph vertices: 13744
# Density : 10.2679
# Reduction factor in vertices : 3.63788
# Reduction factor in edges    : 1.77128
# *****************
# Level 3. Graph vertices: 4570
# Density : 24.7611
# Reduction factor in vertices : 3.00744
# Reduction factor in edges    : 1.24712
# *****************
# Level 4. Graph vertices: 3798
# Density : 29.1069
# Reduction factor in vertices : 1.20326
# Reduction factor in edges    : 1.02361
# *****************
# Level 5. Graph vertices: 3713
# Density : 29.6771
# Reduction factor in vertices : 1.02289
# Reduction factor in edges    : 1.00324
# *****************
# Level 6. Graph vertices: 3696
# Density : 29.789
# Reduction factor in vertices : 1.0046
# Reduction factor in edges    : 1.00083
# *****************
# Level 7. Graph vertices: 3691
# Density : 29.8215
# Reduction factor in vertices : 1.00135
# Reduction factor in edges    : 1.00026
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.140000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 13744
# Density : 10.2679
# Reduction factor in vertices : 3.63788
# Reduction factor in edges    : 1.77128
# *****************
# Level 3. Graph vertices: 4570
# Density : 24.7611
# Reduction factor in vertices : 3.00744
# Reduction factor in edges    : 1.24712
# *****************
# Level 4. Graph vertices: 3798
# Density : 29.1069
# Reduction factor in vertices : 1.20326
# Reduction factor in edges    : 1.02361
# *****************
# Level 5. Graph vertices: 3713
# Density : 29.6771
# Reduction factor in vertices : 1.02289
# Reduction factor in edges    : 1.00324
# *****************
# Level 6. Graph vertices: 3696
# Density : 29.789
# Reduction factor in vertices : 1.0046
# Reduction factor in edges    : 1.00083
# *****************
# Level 7. Graph vertices: 3691
# Density : 29.8215
# Reduction factor in vertices : 1.00135
# Reduction factor in edges    : 1.00026
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.130000 seconds
# Iteration 4, ||r_p||=0.901387, ||r_d||=16.272113, mu=0.071359
# >> >> >>
#
# Level 2. Graph vertices: 13674
# Density : 10.3047
# Reduction factor in vertices : 3.6565
# Reduction factor in edges    : 1.774
# *****************
# Level 3. Graph vertices: 3775
# Density : 29.2728
# Reduction factor in vertices : 3.62225
# Reduction factor in edges    : 1.27511
# *****************
# Level 4. Graph vertices: 2703
# Density : 39.4084
# Reduction factor in vertices : 1.3966
# Reduction factor in edges    : 1.0374
# *****************
# Level 5. Graph vertices: 2609
# Density : 40.6029
# Reduction factor in vertices : 1.03603
# Reduction factor in edges    : 1.00555
# *****************
# Level 6. Graph vertices: 2595
# Density : 40.768
# Reduction factor in vertices : 1.00539
# Reduction factor in edges    : 1.00132
# *****************
# Level 7. Graph vertices: 2593
# Density : 40.7971
# Reduction factor in vertices : 1.00077
# Reduction factor in edges    : 1.00006
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.090000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 13674
# Density : 10.3047
# Reduction factor in vertices : 3.6565
# Reduction factor in edges    : 1.774
# *****************
# Level 3. Graph vertices: 3775
# Density : 29.2728
# Reduction factor in vertices : 3.62225
# Reduction factor in edges    : 1.27511
# *****************
# Level 4. Graph vertices: 2703
# Density : 39.4084
# Reduction factor in vertices : 1.3966
# Reduction factor in edges    : 1.0374
# *****************
# Level 5. Graph vertices: 2609
# Density : 40.6029
# Reduction factor in vertices : 1.03603
# Reduction factor in edges    : 1.00555
# *****************
# Level 6. Graph vertices: 2595
# Density : 40.768
# Reduction factor in vertices : 1.00539
# Reduction factor in edges    : 1.00132
# *****************
# Level 7. Graph vertices: 2593
# Density : 40.7971
# Reduction factor in vertices : 1.00077
# Reduction factor in edges    : 1.00006
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.090000 seconds
# Iteration 5, ||r_p||=0.218614, ||r_d||=3.946492, mu=0.026210
# >> >> >>
#
# Level 2. Graph vertices: 13893
# Density : 10.1895
# Reduction factor in vertices : 3.59886
# Reduction factor in edges    : 1.76577
# *****************
# Level 3. Graph vertices: 3541
# Density : 30.9938
# Reduction factor in vertices : 3.92347
# Reduction factor in edges    : 1.28988
# *****************
# Level 4. Graph vertices: 1606
# Density : 62.7659
# Reduction factor in vertices : 2.20486
# Reduction factor in edges    : 1.08876
# *****************
# Level 5. Graph vertices: 1480
# Density : 67.0446
# Reduction factor in vertices : 1.08514
# Reduction factor in edges    : 1.01588
# *****************
# Level 6. Graph vertices: 1462
# Density : 67.5335
# Reduction factor in vertices : 1.01231
# Reduction factor in edges    : 1.00498
# *****************
# Level 7. Graph vertices: 1459
# Density : 67.6141
# Reduction factor in vertices : 1.00206
# Reduction factor in edges    : 1.00086
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.210000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 13893
# Density : 10.1895
# Reduction factor in vertices : 3.59886
# Reduction factor in edges    : 1.76577
# *****************
# Level 3. Graph vertices: 3541
# Density : 30.9938
# Reduction factor in vertices : 3.92347
# Reduction factor in edges    : 1.28988
# *****************
# Level 4. Graph vertices: 1606
# Density : 62.7659
# Reduction factor in vertices : 2.20486
# Reduction factor in edges    : 1.08876
# *****************
# Level 5. Graph vertices: 1480
# Density : 67.0446
# Reduction factor in vertices : 1.08514
# Reduction factor in edges    : 1.01588
# *****************
# Level 6. Graph vertices: 1462
# Density : 67.5335
# Reduction factor in vertices : 1.01231
# Reduction factor in edges    : 1.00498
# *****************
# Level 7. Graph vertices: 1459
# Density : 67.6141
# Reduction factor in vertices : 1.00206
# Reduction factor in edges    : 1.00086
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.160000 seconds
# Iteration 6, ||r_p||=0.052552, ||r_d||=0.948689, mu=0.011219
# >> >> >>
#
# Level 2. Graph vertices: 14199
# Density : 10.037
# Reduction factor in vertices : 3.5213
# Reduction factor in edges    : 1.75397
# *****************
# Level 3. Graph vertices: 3715
# Density : 29.7187
# Reduction factor in vertices : 3.82207
# Reduction factor in edges    : 1.29084
# *****************
# Level 4. Graph vertices: 1077
# Density : 88.792
# Reduction factor in vertices : 3.4494
# Reduction factor in edges    : 1.15451
# *****************
# Level 5. Graph vertices: 846
# Density : 104.329
# Reduction factor in vertices : 1.27305
# Reduction factor in edges    : 1.08347
# *****************
# Level 6. Graph vertices: 807
# Density : 105.399
# Reduction factor in vertices : 1.04833
# Reduction factor in edges    : 1.03768
# *****************
# Level 7. Graph vertices: 799
# Density : 105.058
# Reduction factor in vertices : 1.01001
# Reduction factor in edges    : 1.0133
# *****************
# Level 8. Graph vertices: 791
# Density : 104.985
# Reduction factor in vertices : 1.01011
# Reduction factor in edges    : 1.01081
# *****************
# Level 9. Graph vertices: 789
# Density : 105.144
# Reduction factor in vertices : 1.00253
# Reduction factor in edges    : 1.00101
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.120000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14199
# Density : 10.037
# Reduction factor in vertices : 3.5213
# Reduction factor in edges    : 1.75397
# *****************
# Level 3. Graph vertices: 3715
# Density : 29.7187
# Reduction factor in vertices : 3.82207
# Reduction factor in edges    : 1.29084
# *****************
# Level 4. Graph vertices: 1077
# Density : 88.792
# Reduction factor in vertices : 3.4494
# Reduction factor in edges    : 1.15451
# *****************
# Level 5. Graph vertices: 846
# Density : 104.329
# Reduction factor in vertices : 1.27305
# Reduction factor in edges    : 1.08347
# *****************
# Level 6. Graph vertices: 807
# Density : 105.399
# Reduction factor in vertices : 1.04833
# Reduction factor in edges    : 1.03768
# *****************
# Level 7. Graph vertices: 799
# Density : 105.058
# Reduction factor in vertices : 1.01001
# Reduction factor in edges    : 1.0133
# *****************
# Level 8. Graph vertices: 791
# Density : 104.985
# Reduction factor in vertices : 1.01011
# Reduction factor in edges    : 1.01081
# *****************
# Level 9. Graph vertices: 789
# Density : 105.144
# Reduction factor in vertices : 1.00253
# Reduction factor in edges    : 1.00101
# *****************
# Warning: CMG convergence may be slow due to matrix density. Future versions of
# CMG will eliminate this problem.]
# > In hierarchy (line 195)
#   In cmg_dd (line 92)
#   In cmg_sdd (line 41)]
# Hierarchy constructed in 0.170000 seconds
# Iteration 7, ||r_p||=0.010869, ||r_d||=0.196205, mu=0.005185
# >> >> >>
#
# Level 2. Graph vertices: 14360
# Density : 9.95836
# Reduction factor in vertices : 3.48182
# Reduction factor in edges    : 1.748
# *****************
# Level 3. Graph vertices: 3862
# Density : 28.696
# Reduction factor in vertices : 3.71828
# Reduction factor in edges    : 1.29035
# *****************
# Level 4. Graph vertices: 1010
# Density : 94.1386
# Reduction factor in vertices : 3.82376
# Reduction factor in edges    : 1.16559
# *****************
# Level 5. Graph vertices: 531
# Density : 136.94
# Reduction factor in vertices : 1.90207
# Reduction factor in edges    : 1.30757
# *****************
# Level 6. Graph vertices: 475
# Density : 134.128
# Reduction factor in vertices : 1.11789
# Reduction factor in edges    : 1.14133
# *****************
# Hierarchy constructed in 3.550000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14360
# Density : 9.95836
# Reduction factor in vertices : 3.48182
# Reduction factor in edges    : 1.748
# *****************
# Level 3. Graph vertices: 3862
# Density : 28.696
# Reduction factor in vertices : 3.71828
# Reduction factor in edges    : 1.29035
# *****************
# Level 4. Graph vertices: 1010
# Density : 94.1386
# Reduction factor in vertices : 3.82376
# Reduction factor in edges    : 1.16559
# *****************
# Level 5. Graph vertices: 531
# Density : 136.94
# Reduction factor in vertices : 1.90207
# Reduction factor in edges    : 1.30757
# *****************
# Level 6. Graph vertices: 475
# Density : 134.128
# Reduction factor in vertices : 1.11789
# Reduction factor in edges    : 1.14133
# *****************
# Hierarchy constructed in 4.400000 seconds
# Iteration 8, ||r_p||=0.002098, ||r_d||=0.037867, mu=0.002788
# >> >> >>
#
# Level 2. Graph vertices: 14438
# Density : 9.92063
# Reduction factor in vertices : 3.46301
# Reduction factor in edges    : 1.74517
# *****************
# Level 3. Graph vertices: 3890
# Density : 28.5208
# Reduction factor in vertices : 3.71157
# Reduction factor in edges    : 1.29102
# *****************
# Level 4. Graph vertices: 996
# Density : 95.1968
# Reduction factor in vertices : 3.90562
# Reduction factor in edges    : 1.17012
# *****************
# Level 5. Graph vertices: 373
# Density : 157.134
# Reduction factor in vertices : 2.67024
# Reduction factor in edges    : 1.61772
# *****************
# Hierarchy constructed in 1.520000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14438
# Density : 9.92063
# Reduction factor in vertices : 3.46301
# Reduction factor in edges    : 1.74517
# *****************
# Level 3. Graph vertices: 3890
# Density : 28.5208
# Reduction factor in vertices : 3.71157
# Reduction factor in edges    : 1.29102
# *****************
# Level 4. Graph vertices: 996
# Density : 95.1968
# Reduction factor in vertices : 3.90562
# Reduction factor in edges    : 1.17012
# *****************
# Level 5. Graph vertices: 373
# Density : 157.134
# Reduction factor in vertices : 2.67024
# Reduction factor in edges    : 1.61772
# *****************
# Hierarchy constructed in 1.570000 seconds
# Iteration 9, ||r_p||=0.000119, ||r_d||=0.002149, mu=0.001118
# >> >> >>
#
# Level 2. Graph vertices: 14440
# Density : 9.91911
# Reduction factor in vertices : 3.46253
# Reduction factor in edges    : 1.74519
# *****************
# Level 3. Graph vertices: 3913
# Density : 28.3867
# Reduction factor in vertices : 3.69026
# Reduction factor in edges    : 1.28948
# *****************
# Level 4. Graph vertices: 1007
# Density : 94.3823
# Reduction factor in vertices : 3.8858
# Reduction factor in edges    : 1.1687
# *****************
# Level 5. Graph vertices: 276
# Density : 167.688
# Reduction factor in vertices : 3.64855
# Reduction factor in edges    : 2.05356
# *****************
# Hierarchy constructed in 0.930000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14440
# Density : 9.91911
# Reduction factor in vertices : 3.46253
# Reduction factor in edges    : 1.74519
# *****************
# Level 3. Graph vertices: 3913
# Density : 28.3867
# Reduction factor in vertices : 3.69026
# Reduction factor in edges    : 1.28948
# *****************
# Level 4. Graph vertices: 1007
# Density : 94.3823
# Reduction factor in vertices : 3.8858
# Reduction factor in edges    : 1.1687
# *****************
# Level 5. Graph vertices: 276
# Density : 167.688
# Reduction factor in vertices : 3.64855
# Reduction factor in edges    : 2.05356
# *****************
# Hierarchy constructed in 1.010000 seconds
# Iteration 10, ||r_p||=0.000015, ||r_d||=0.000265, mu=0.000459
# >> >> >>
#
# Level 2. Graph vertices: 14460
# Density : 9.90982
# Reduction factor in vertices : 3.45775
# Reduction factor in edges    : 1.74441
# *****************
# Level 3. Graph vertices: 3960
# Density : 28.0894
# Reduction factor in vertices : 3.65152
# Reduction factor in edges    : 1.28824
# *****************
# Level 4. Graph vertices: 1042
# Density : 91.7179
# Reduction factor in vertices : 3.80038
# Reduction factor in edges    : 1.1639
# *****************
# Level 5. Graph vertices: 265
# Density : 170.162
# Reduction factor in vertices : 3.93208
# Reduction factor in edges    : 2.1194
# *****************
# Hierarchy constructed in 1.000000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14460
# Density : 9.90982
# Reduction factor in vertices : 3.45775
# Reduction factor in edges    : 1.74441
# *****************
# Level 3. Graph vertices: 3960
# Density : 28.0894
# Reduction factor in vertices : 3.65152
# Reduction factor in edges    : 1.28824
# *****************
# Level 4. Graph vertices: 1042
# Density : 91.7179
# Reduction factor in vertices : 3.80038
# Reduction factor in edges    : 1.1639
# *****************
# Level 5. Graph vertices: 265
# Density : 170.162
# Reduction factor in vertices : 3.93208
# Reduction factor in edges    : 2.1194
# *****************
# Hierarchy constructed in 1.150000 seconds
# Iteration 11, ||r_p||=0.000002, ||r_d||=0.000035, mu=0.000275
# >> >> >>
#
# Level 2. Graph vertices: 14483
# Density : 9.89816
# Reduction factor in vertices : 3.45225
# Reduction factor in edges    : 1.74369
# *****************
# Level 3. Graph vertices: 3986
# Density : 27.9303
# Reduction factor in vertices : 3.63347
# Reduction factor in edges    : 1.28766
# *****************
# Level 4. Graph vertices: 1067
# Density : 90.2146
# Reduction factor in vertices : 3.73571
# Reduction factor in edges    : 1.15657
# *****************
# Level 5. Graph vertices: 279
# Density : 172.842
# Reduction factor in vertices : 3.82437
# Reduction factor in edges    : 1.99612
# *****************
# Hierarchy constructed in 0.950000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14483
# Density : 9.89816
# Reduction factor in vertices : 3.45225
# Reduction factor in edges    : 1.74369
# *****************
# Level 3. Graph vertices: 3986
# Density : 27.9303
# Reduction factor in vertices : 3.63347
# Reduction factor in edges    : 1.28766
# *****************
# Level 4. Graph vertices: 1067
# Density : 90.2146
# Reduction factor in vertices : 3.73571
# Reduction factor in edges    : 1.15657
# *****************
# Level 5. Graph vertices: 279
# Density : 172.842
# Reduction factor in vertices : 3.82437
# Reduction factor in edges    : 1.99612
# *****************
# Hierarchy constructed in 0.640000 seconds
# Iteration 12, ||r_p||=0.000001, ||r_d||=0.000011, mu=0.000112
# >> >> >>
#
# Level 2. Graph vertices: 14488
# Density : 9.89564
# Reduction factor in vertices : 3.45106
# Reduction factor in edges    : 1.74353
# *****************
# Level 3. Graph vertices: 4025
# Density : 27.6912
# Reduction factor in vertices : 3.5995
# Reduction factor in edges    : 1.28631
# *****************
# Level 4. Graph vertices: 1073
# Density : 89.822
# Reduction factor in vertices : 3.75116
# Reduction factor in edges    : 1.15644
# *****************
# Level 5. Graph vertices: 286
# Density : 174.42
# Reduction factor in vertices : 3.75175
# Reduction factor in edges    : 1.93206
# *****************
# Hierarchy constructed in 0.610000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14488
# Density : 9.89564
# Reduction factor in vertices : 3.45106
# Reduction factor in edges    : 1.74353
# *****************
# Level 3. Graph vertices: 4025
# Density : 27.6912
# Reduction factor in vertices : 3.5995
# Reduction factor in edges    : 1.28631
# *****************
# Level 4. Graph vertices: 1073
# Density : 89.822
# Reduction factor in vertices : 3.75116
# Reduction factor in edges    : 1.15644
# *****************
# Level 5. Graph vertices: 286
# Density : 174.42
# Reduction factor in vertices : 3.75175
# Reduction factor in edges    : 1.93206
# *****************
# Hierarchy constructed in 0.680000 seconds
# Iteration 13, ||r_p||=0.000000, ||r_d||=0.000001, mu=0.000050
# >> >> >>
#
# Level 2. Graph vertices: 14493
# Density : 9.8934
# Reduction factor in vertices : 3.44987
# Reduction factor in edges    : 1.74333
# *****************
# Level 3. Graph vertices: 4032
# Density : 27.6493
# Reduction factor in vertices : 3.59449
# Reduction factor in edges    : 1.28617
# *****************
# Level 4. Graph vertices: 1085
# Density : 88.9631
# Reduction factor in vertices : 3.71613
# Reduction factor in edges    : 1.15495
# *****************
# Level 5. Graph vertices: 293
# Density : 174.099
# Reduction factor in vertices : 3.70307
# Reduction factor in edges    : 1.89224
# *****************
# Hierarchy constructed in 0.610000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14493
# Density : 9.8934
# Reduction factor in vertices : 3.44987
# Reduction factor in edges    : 1.74333
# *****************
# Level 3. Graph vertices: 4032
# Density : 27.6493
# Reduction factor in vertices : 3.59449
# Reduction factor in edges    : 1.28617
# *****************
# Level 4. Graph vertices: 1085
# Density : 88.9631
# Reduction factor in vertices : 3.71613
# Reduction factor in edges    : 1.15495
# *****************
# Level 5. Graph vertices: 293
# Density : 174.099
# Reduction factor in vertices : 3.70307
# Reduction factor in edges    : 1.89224
# *****************
# Hierarchy constructed in 0.610000 seconds
# Iteration 14, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000022
# >> >> >>
#
# Level 2. Graph vertices: 14501
# Density : 9.88959
# Reduction factor in vertices : 3.44797
# Reduction factor in edges    : 1.74304
# *****************
# Level 3. Graph vertices: 4037
# Density : 27.6203
# Reduction factor in vertices : 3.59202
# Reduction factor in edges    : 1.28614
# *****************
# Level 4. Graph vertices: 1096
# Density : 88.1277
# Reduction factor in vertices : 3.68339
# Reduction factor in edges    : 1.15442
# *****************
# Level 5. Graph vertices: 304
# Density : 177.592
# Reduction factor in vertices : 3.60526
# Reduction factor in edges    : 1.78906
# *****************
# Hierarchy constructed in 0.720000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14501
# Density : 9.88959
# Reduction factor in vertices : 3.44797
# Reduction factor in edges    : 1.74304
# *****************
# Level 3. Graph vertices: 4037
# Density : 27.6203
# Reduction factor in vertices : 3.59202
# Reduction factor in edges    : 1.28614
# *****************
# Level 4. Graph vertices: 1096
# Density : 88.1277
# Reduction factor in vertices : 3.68339
# Reduction factor in edges    : 1.15442
# *****************
# Level 5. Graph vertices: 304
# Density : 177.592
# Reduction factor in vertices : 3.60526
# Reduction factor in edges    : 1.78906
# *****************
# Hierarchy constructed in 0.730000 seconds
# Iteration 15, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000010
# >> >> >>
#
# Level 2. Graph vertices: 14496
# Density : 9.89197
# Reduction factor in vertices : 3.44916
# Reduction factor in edges    : 1.74322
# *****************
# Level 3. Graph vertices: 4029
# Density : 27.6706
# Reduction factor in vertices : 3.59792
# Reduction factor in edges    : 1.28622
# *****************
# Level 4. Graph vertices: 1103
# Density : 87.5947
# Reduction factor in vertices : 3.65277
# Reduction factor in edges    : 1.15389
# *****************
# Level 5. Graph vertices: 306
# Density : 176.124
# Reduction factor in vertices : 3.60458
# Reduction factor in edges    : 1.79272
# *****************
# Hierarchy constructed in 0.740000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14496
# Density : 9.89197
# Reduction factor in vertices : 3.44916
# Reduction factor in edges    : 1.74322
# *****************
# Level 3. Graph vertices: 4029
# Density : 27.6706
# Reduction factor in vertices : 3.59792
# Reduction factor in edges    : 1.28622
# *****************
# Level 4. Graph vertices: 1103
# Density : 87.5947
# Reduction factor in vertices : 3.65277
# Reduction factor in edges    : 1.15389
# *****************
# Level 5. Graph vertices: 306
# Density : 176.124
# Reduction factor in vertices : 3.60458
# Reduction factor in edges    : 1.79272
# *****************
# Hierarchy constructed in 0.720000 seconds
# Iteration 16, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000004
# >> >> >>
#
# Level 2. Graph vertices: 14481
# Density : 9.89925
# Reduction factor in vertices : 3.45273
# Reduction factor in edges    : 1.74374
# *****************
# Level 3. Graph vertices: 4020
# Density : 27.7249
# Reduction factor in vertices : 3.60224
# Reduction factor in edges    : 1.28619
# *****************
# Level 4. Graph vertices: 1097
# Density : 87.9881
# Reduction factor in vertices : 3.66454
# Reduction factor in edges    : 1.15469
# *****************
# Level 5. Graph vertices: 306
# Density : 176.562
# Reduction factor in vertices : 3.58497
# Reduction factor in edges    : 1.78654
# *****************
# Hierarchy constructed in 0.780000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14481
# Density : 9.89925
# Reduction factor in vertices : 3.45273
# Reduction factor in edges    : 1.74374
# *****************
# Level 3. Graph vertices: 4020
# Density : 27.7249
# Reduction factor in vertices : 3.60224
# Reduction factor in edges    : 1.28619
# *****************
# Level 4. Graph vertices: 1097
# Density : 87.9881
# Reduction factor in vertices : 3.66454
# Reduction factor in edges    : 1.15469
# *****************
# Level 5. Graph vertices: 306
# Density : 176.562
# Reduction factor in vertices : 3.58497
# Reduction factor in edges    : 1.78654
# *****************
# Hierarchy constructed in 0.730000 seconds
# Iteration 17, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000002
# >> >> >>
#
# Level 2. Graph vertices: 14489
# Density : 9.89544
# Reduction factor in vertices : 3.45082
# Reduction factor in edges    : 1.74345
# *****************
# Level 3. Graph vertices: 4023
# Density : 27.7054
# Reduction factor in vertices : 3.60154
# Reduction factor in edges    : 1.28635
# *****************
# Level 4. Graph vertices: 1097
# Density : 87.9809
# Reduction factor in vertices : 3.66727
# Reduction factor in edges    : 1.15484
# *****************
# Level 5. Graph vertices: 302
# Density : 175.205
# Reduction factor in vertices : 3.63245
# Reduction factor in edges    : 1.82407
# *****************
# Hierarchy constructed in 0.690000 seconds
# >> >> >>
#
# Level 2. Graph vertices: 14489
# Density : 9.89544
# Reduction factor in vertices : 3.45082
# Reduction factor in edges    : 1.74345
# *****************
# Level 3. Graph vertices: 4023
# Density : 27.7054
# Reduction factor in vertices : 3.60154
# Reduction factor in edges    : 1.28635
# *****************
# Level 4. Graph vertices: 1097
# Density : 87.9809
# Reduction factor in vertices : 3.66727
# Reduction factor in edges    : 1.15484
# *****************
# Level 5. Graph vertices: 302
# Density : 175.205
# Reduction factor in vertices : 3.63245
# Reduction factor in edges    : 1.82407
# *****************
# Hierarchy constructed in 0.700000 seconds
# Iteration 18, ||r_p||=0.000000, ||r_d||=0.000000, mu=0.000001
# Termination tolerance reached.
# 119.329313 seconds (10.57 M allocations: 8.269 GB, 6.92% gc time)

# %% [markdown]
# That was the fastest.  But, there wasn't a huge amount of difference between the solvers, other than the cholesky one.  We should check if there is another part of the code that is taking a lot of time.
